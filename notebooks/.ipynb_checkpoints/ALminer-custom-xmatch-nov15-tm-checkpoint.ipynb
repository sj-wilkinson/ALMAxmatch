# %%
import alminer, pandas, pymysql, time, glob, os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
def build_tmp_table(ra, dec, search_radius_arcmin):
    
    # construct a temporary table from template

    template_file = 'template_tap.txt'
    path_to_template = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    table_file = 'sdss_positions_tap.txt'
    path_to_file = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    os.system(f'cp {path_to_template + template_file} {path_to_file + table_file}')

    # get template table (formatting with no coordinates)
    out = open(path_to_file + table_file, 'r')
    out_data = out.read()
    out.close()

    search_radius_deg = search_radius_arcmin/60

    # initialize string
    coords_str = ''

    # format the ra and dec's for html table
    for r, d in zip(ra, dec):

        coords_str += "          <TR>\n" 
        coords_str += f"            <TD>{r}</TD>\n"
        coords_str += f"            <TD>{d}</TD>\n"
        coords_str += "          </TR>\n"
        coords_str += "\n"

    # replace __COORDS__ in template with formatted coords
    out_data = out_data.replace('          __COORDS__', coords_str)

    # write to new table
    out = open(path_to_file + table_file, 'w')
    out.write(out_data)
    out.close()
    
    return table_file, path_to_file

def generate_query(ra, dec, search_radius_arcmin = 0.5):
    
    # generate a custom ALminer query from a list of known hits

    query_str = "SELECT * FROM ivoa.ObsCore WHERE data_rights LIKE '%Public%' AND ("

    search_radius_deg = search_radius_arcmin/60

    initialized = False

    for r, d in zip(ra, dec):

        if not initialized:

            query_str += f"1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
            initialized = True

        else: 

            query_str += f"OR 1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 

        query_str += f"OR 1 = CONTAINS(POINT('ICRS',{r},{d}), s_region) "

    query_str += ')'
    
    return query_str

# %%
#Query MySQL for SDSS positions
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
mass_sdss = data[3]
z_sdss = data[4]

# %%
len(ra_sdss)
# Out:
# 568753

# %%
# split up targets into separate jobs (nJobs)
nJobs = 300

# number of targets in each job
N = int(np.ceil(len(ra_sdss)/nJobs))
print(N)

# number of completed jobs to start from
completed = 0

# search radius of query
search_radius_arcmin = 0.167 # 10 arcsec
search_radius_deg = search_radius_arcmin/60

# run query jobs in serial    
for i in np.arange(completed, nJobs, 1):
    
    ## splitting up targets into manageable subset
    if i == nJobs-1:
    
        ra_table = ra_sdss[i*N:]
        dec_table = dec_sdss[i*N:]
        
    else:
    
        ra_table = ra_sdss[i*N:(i+1)*N]
        dec_table = dec_sdss[i*N:(i+1)*N]
        
    ###### query ALMA archive to match subset with a temporary HTML table and cadc-tap #######
        
    ## create temporary table with target subset    
    table_file, path_to_table = build_tmp_table(ra_table, dec_table, search_radius_arcmin = search_radius_arcmin)
    
    output_file = 'sdss_x_alma_positions.txt'
    path_to_output = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    # wipe old output file
    tmp = open(path_to_output+output_file, 'w')
    tmp.close()
    
    ## query with cadc-tap
    start = time.time()
    os.system(f'cadc-tap query -s https://almascience.nao.ac.jp/tap --tmptable mytable:{path_to_table + table_file} \
            "SELECT DISTINCT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t \
            ON 1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, {search_radius_deg}), oc.s_region) AND oc.data_rights LIKE \'%Public%\'"\
            > {path_to_output + output_file}')
    end = time.time()
    print(f'Querying {N} galaxies took {(end-start)/60} min.')
    
    ########################################################################################
    
    ################## convert results to an ALminer query object ##########################
    
    # remove last two lines of the text file

    out = open(path_to_output + output_file, 'r')
    lines = out.readlines()
    out.close()

    lines = lines[:-2]

    out = open(path_to_output + output_file, 'w')
    out.write(''.join(lines))
    out.close()
    
    if len(lines) < 3:
        print('No matches!')
        continue
    
    # collect ra and dec of all sub-band ra-dec
    ra_match, dec_match = np.loadtxt(path_to_output + output_file, unpack = True, skiprows = 2)
    
    #print(type(ra_match), type(dec_match))
    
    if type(ra_match) == np.float64:
        ra_match_unique = np.array([ra_match])
        dec_match_unique = np.array([dec_match])
        
    else:

        # generate strings of ra_dec pairs to identify unique targets
        rd_str = np.array([f'{r}_{d}' for r, d in zip(ra_match, dec_match)])

        # identify unique targets from xmatch output
        rd_str_unique, index_unique = np.unique(rd_str, return_index = True)
        ra_match_unique = ra_match[index_unique]
        dec_match_unique = dec_match[index_unique]
    
    # generate a custom ALminer query from xmatch hits
    query_str = generate_query(ra_match_unique, dec_match_unique, search_radius_arcmin = search_radius_arcmin)
    
    start = time.time()
    myquery = alminer.run_query(query_str)
    myquery = alminer.filter_results(myquery)
    end = time.time()
    print(f'This query took {(end-start)/60} min.')

    # if there are observations found, print out summary and save for later
    if myquery is None:
        print('No observations found in query.')
    else:
        
        # print out summary
        #alminer.summary(myquery)
        
        # pickle data for later
        myquery.to_pickle(f'/arc/projects/salvage/ALMAxmatch/ALminer_output/SDSS-ALMA-search-Nov14-Job{i}.pkl')
        
        
    ########################################################################################
# Out:
# 1896
# Querying 1896 galaxies took 0.28407676219940187 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 4 target(s) with ALMA data = ['SDSS_J152224.73-004404.5', '105386', 'HATLASJ121253.5-002203', 'HATLASJ121253']
# --------------------------------
# This query took 0.04012387196222941 min.
# Querying 1896 galaxies took 0.2823257406552633 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 17
# Number of unique subbands = 60
# Total number of subbands = 68
# 11 target(s) with ALMA data = ['1237648705664450617', 'HATLAS_J140608.2+005501', 'HATLAS_J143336.7+005042', '1237648704051675158', 'UR7G', 'HATLAS_RED_2221', 'GAMA106389', 'GAMA64646', 'HATLAS1745', 'HATLAS1114', 'HATLAS1744']
# --------------------------------
# This query took 0.043445909023284913 min.
# Querying 1896 galaxies took 0.3516865054766337 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 6
# Number of unique subbands = 24
# Total number of subbands = 24
# 3 target(s) with ALMA data = ['J0103+1526', 'PM1_9195_3702', '015028']
# --------------------------------
# This query took 0.03379063606262207 min.
# Querying 1896 galaxies took 0.22580458323160807 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 21
# Number of unique subbands = 66
# Total number of subbands = 74
# 9 target(s) with ALMA data = ['1237649961382772816', 'NGC_985', 'G04-1', 'HE0232-0900', 'VV285', '8728-3701', 'HATLAS350', 'PM1_9195_3703', 'HATLAS850']
# --------------------------------
# This query took 0.04825313488642375 min.
# ERROR:: failed to read table mytable from https://almascience.nao.ac.jp/tap/files/sdss_positions_tap.txt-wooqrxre5a5c1ljr
# Querying 1896 galaxies took 0.029576309521993003 min.
# No matches!
# Querying 1896 galaxies took 0.262120791276296 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 12
# Total number of subbands = 16
# 4 target(s) with ALMA data = ['HATLAS1703', 'HATLAS1701', '538220', 'SHOC_391']
# --------------------------------
# This query took 0.027055835723876952 min.
# Querying 1896 galaxies took 0.31222732067108155 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['CP_9195_9101', 'D13-5', '021348']
# --------------------------------
# This query took 0.03033514420191447 min.
# Querying 1896 galaxies took 0.3435937484105428 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 23
# Total number of subbands = 27
# 3 target(s) with ALMA data = ['RFGC229', 'CGCG_436-030', 'CGCG436-030']
# --------------------------------
# This query took 0.03797978162765503 min.
# Querying 1896 galaxies took 0.2600752115249634 min.
# --------------------------------
# Number of projects = 14
# Number of observations = 21
# Number of unique subbands = 81
# Total number of subbands = 81
# 9 target(s) with ALMA data = ['1237671764248363271', 'HATLAS979', 'A1689-zD1', 'A1689-1829', 'A1689-1292', 'a1689', '123988', 'SDSS_J122646.97-011854.0', 'A1689-ZD1']
# --------------------------------
# This query took 0.043657565116882326 min.
# Querying 1896 galaxies took 0.23845548629760743 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 11
# Number of unique subbands = 36
# Total number of subbands = 44
# 10 target(s) with ALMA data = ['HATLAS932', 'HATLAS413', 'HATLAS876', 'G09.v2.42', 'UM461', 'HOT2_EI_CII_G09.v2.42', 'HATLAS_J092031.6-004936', 'HATLAS_J092014.6-004328', 'GAMA177186', '1J091205.8+002656']
# --------------------------------
# This query took 0.03883084456125895 min.
# Querying 1896 galaxies took 0.20146134694417317 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 9
# Number of unique subbands = 36
# Total number of subbands = 36
# 8 target(s) with ALMA data = ['HATLAS678', 'HATLASJ090223', 'G09.v2.55', 'HATLASJ090223.9-001639', 'J0847-0022', '470573', 'HOT2_EI_CII_G09.v2.55', 'HATLAS_J092156.5-001538']
# --------------------------------
# This query took 0.040220582485198976 min.
# Querying 1896 galaxies took 0.25979358752568565 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 11
# Number of unique subbands = 32
# Total number of subbands = 40
# 11 target(s) with ALMA data = ['HATLAS1755', 'HATLAS1706', 'HATLAS1181', 'HATLAS1720', 'HATLAS1034', 'rs0767', 'HATLAS_RED_2210', 'GAMA238125', 'GAMA228432', 'C13-1', 'APX_SB2_3']
# --------------------------------
# This query took 0.037384299437205 min.
# Querying 1896 galaxies took 0.2219805399576823 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 20
# Total number of subbands = 24
# 5 target(s) with ALMA data = ['HATLAS_J145013.2+012125', 'AGC249559', '122665', '136638', 'GAMA239376']
# --------------------------------
# This query took 0.033141167958577473 min.
# Querying 1896 galaxies took 0.19450802405675252 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 6
# Number of unique subbands = 12
# Total number of subbands = 20
# 6 target(s) with ALMA data = ['HATLAS1113', 'HATLAS1016', 'HATLAS839', 'rs0769', 'rs0768', 'GAMA272990']
# --------------------------------
# This query took 0.03232421477635702 min.
# Querying 1896 galaxies took 0.24970964590708414 min.
# --------------------------------
# Number of projects = 16
# Number of observations = 30
# Number of unique subbands = 109
# Total number of subbands = 113
# 15 target(s) with ALMA data = ['HATLAS_J144244.2+015846', 'HATLAS_J141235.5+023130', 'HATLAS_J145019.0+015206', '1237651736305402018', 'rs0680', 'rs0677', 'rs0679', 'IRAS12112+0305', 'IRAS_F12112+0305', 'APEX_SB14', 'irasf12112+0305', 'Q14286+0210', 'IRAS_12112+0305', 'HATLAS1781', 'HATLAS1733']
# --------------------------------
# This query took 0.07556095520655313 min.
# Querying 1896 galaxies took 0.21979008515675863 min.
# --------------------------------
# Number of projects = 27
# Number of observations = 37
# Number of unique subbands = 131
# Total number of subbands = 139
# 8 target(s) with ALMA data = ['J1512+0203', 'G09.v2.107', '323889', 'APEX_SB17', 'HATLASJ085616.0+005237', 'HOT2_EI_CII_G09.v2.107', 'J085547.66+004739.4', 'HATLASJ085616']
# --------------------------------
# This query took 0.08043538729349772 min.
# Querying 1896 galaxies took 0.2411462187767029 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 8
# Number of unique subbands = 24
# Total number of subbands = 32
# 8 target(s) with ALMA data = ['1237651754549706790', 'HATLAS1190', 'HATLAS1100', 'UGC07841', '440644', '501763', 'dm1106+01_I096', 'dm1106+01_I095']
# --------------------------------
# This query took 0.032338309288024905 min.
# Querying 1896 galaxies took 0.24558554887771605 min.
# --------------------------------
# Number of projects = 11
# Number of observations = 26
# Number of unique subbands = 103
# Total number of subbands = 120
# 15 target(s) with ALMA data = ['AT2018hyz', 'AS2COS0157.1', 'XrayOpt_TDE1_ASASSN-18z', 'COS850.0157', 'J1313', 'HOT2_EI_CII_G09.v2.137', 'HATLAS_J084552.0+011121', 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167', 'Q09498+0155', 'GEMS-N4636-18', 'Ceres', 'UGC07824', 'G09.v2.167', 'G09.v2.137']
# --------------------------------
# This query took 0.059930511315663654 min.
# Querying 1896 galaxies took 0.21435247659683226 min.
# --------------------------------
# Number of projects = 39
# Number of observations = 73
# Number of unique subbands = 243
# Total number of subbands = 324
# 55 target(s) with ALMA data = ['COSp_17', 'HATLAS_J144652.0+014010', 'KMOS3DCOS4-19680', 'COSMOS-1411106', 'COS-2800', 'VUDS5101233539', 'GAMA348116', 'VUDS5101234193', 'mosdef_z21_109_m20', 'AS2COS0103.1', '712919', 'HATLASJ142057.9+015233', 'HATLASJ091157.2+014453', 'HATLASJ090120.7+020223', 'COSMOS-20062', 'COSMOS-19753', 'COSMOS-3666', 'COSMOS-SBC3', 'COS850.0187', 'COS850.0103', 'COS850.0014', 'POS-16', '0480_580_51989', 'ZF-COS-19589', 'POS-04', 'POS-01', 'POS-21', 'DSFG850.44', 'HOT2_EI_CII_G09.v2.52', 'COS.0094', 'HOT2_EI_CII_G09.v2.103', 'HATLAS_J084458.3+014027', 'HOT2_EI_CII_G09.v2.26', 'AS2COS014.1', 'POS-19', 'mosdef_3692', 'POS-02', 'Tune139', 'COS.0068', 'AS2COS0014.1', 'Tune147', '600465', '2-16165', 'AzTECC95', 'AzTECC11', '2MASXJ14161186+0152048', 'UVISTA-Z-349', 'DSFGJ100018', 'G09.v2.52', 'cosmos_148908', 'G09.v2.26', 'HATLASJ142057', 'HATLASJ091157', 'G09.v2.103', 'MASOSA']
# --------------------------------
# This query took 0.10397305091222127 min.
# Querying 1896 galaxies took 0.21399497985839844 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 4
# Number of unique subbands = 13
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['AGC242091', 'AGC242147', 'SDSS_J150904.22+043441.8']
# --------------------------------
# This query took 0.03094751834869385 min.
# Querying 1896 galaxies took 0.24477389653523762 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 20
# Total number of subbands = 20
# 2 target(s) with ALMA data = ['Neptune', 'SDSS_J213333.31-071249.2']
# --------------------------------
# This query took 0.0343985120455424 min.
# Querying 1896 galaxies took 0.1893349568049113 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['SDSS013527-1039']
# --------------------------------
# This query took 0.027374597390492757 min.
# Querying 1896 galaxies took 0.19316574335098266 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['1237652630714122400', '1237652901832294517']
# --------------------------------
# This query took 0.026269328594207764 min.
# Querying 1896 galaxies took 0.20294859409332275 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 17
# Number of unique subbands = 60
# Total number of subbands = 61
# 4 target(s) with ALMA data = ['J2222+1213', 'manga_7977-3704', '7815-12705', 'MACSJ2155.6+1231']
# --------------------------------
# This query took 0.04217987457911174 min.
# Querying 1896 galaxies took 0.1842627763748169 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 20
# Total number of subbands = 20
# 3 target(s) with ALMA data = ['CGCG429-012', 'A1835', 'Abell 1835']
# --------------------------------
# This query took 0.03375533819198608 min.
# Querying 1896 galaxies took 0.2037356376647949 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['HATLAS_J143601.6+022933']
# --------------------------------
# This query took 0.025704487164815267 min.
# Querying 1896 galaxies took 0.22767502864201863 min.
# --------------------------------
# Number of projects = 9
# Number of observations = 13
# Number of unique subbands = 33
# Total number of subbands = 40
# 6 target(s) with ALMA data = ['Neptune', 'Q21303-0840', 'G20-2', '0637_584_52174', '210358', 'G_20-2']
# --------------------------------
# This query took 0.05810936292012533 min.
# Querying 1896 galaxies took 0.21004759470621745 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 21
# Number of unique subbands = 48
# Total number of subbands = 84
# 4 target(s) with ALMA data = ['GRB190829A', 'GRB', 'GRB_190829A', 'dm0035-10']
# --------------------------------
# This query took 0.06564594507217407 min.
# Querying 1896 galaxies took 0.189508318901062 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 13
# Number of unique subbands = 52
# Total number of subbands = 52
# 2 target(s) with ALMA data = ['1237652901308793003', 'J2358-1020']
# --------------------------------
# This query took 0.03527452150980632 min.
# Querying 1896 galaxies took 0.20885045925776163 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 10
# 3 target(s) with ALMA data = ['CP_7977_9102', '587727221402042402_7977-3703', '8618-9102']
# --------------------------------
# This query took 0.029916040102640786 min.
# Querying 1896 galaxies took 0.336894949277242 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['3FGL_J0056.3-0935']
# --------------------------------
# This query took 0.031062678496042887 min.
# Querying 1896 galaxies took 0.3162664810816447 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 11
# Number of unique subbands = 31
# Total number of subbands = 46
# 4 target(s) with ALMA data = ['IRAS_F01364-1042', 'IRASF01364-1042', 'J0123-0923', 'IRAS01364-1042']
# --------------------------------
# This query took 0.04573567310969035 min.
# Querying 1896 galaxies took 0.20235308011372885 min.
# --------------------------------
# Number of projects = 23
# Number of observations = 45
# Number of unique subbands = 131
# Total number of subbands = 180
# 31 target(s) with ALMA data = ['CS_AGN30', '1237648722830688271', 'COSMOS-1200839', 'COSMOS-0969208', 'COSMOS-1197519', 'ZCOS09', '265143', 'COSMOS-19753', 'z12_22', 'z12_92', 'POS-21', 'DSFG850.44', 'HOT2_EI_CII_G09.v2.77', 'highz_cell6_227478', 'HOT2_EI_CII_G09.v2.38', 'HOT2_EI_CII_G09.v2.58', 'Tune139', 'POS-19', 'mosdef_20331', 'COS.0090', 'Tune147', '960713', '18380', 'AzTECC24b', 'AzTECC85', 'AzTECC87', 'COSMOSVLA3_225', 'COSMOS-32932', 'COSJ100009.49+022219.6', 'G09.v2.77', 'ZF-COS-18842']
# --------------------------------
# This query took 0.12485467990239461 min.
# Querying 1896 galaxies took 0.19347867568333943 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 7
# Number of unique subbands = 15
# Total number of subbands = 28
# 5 target(s) with ALMA data = ['JO201_CO21', 'JO201_CO21B', 'JO201_CO10B', 'JO201_CO10', '150056']
# --------------------------------
# This query took 0.03711357514063517 min.
# Querying 1896 galaxies took 0.2064079244931539 min.
# --------------------------------
# Number of projects = 9
# Number of observations = 16
# Number of unique subbands = 52
# Total number of subbands = 63
# 11 target(s) with ALMA data = ['IRAS_01166-0844', 'G09.v2.235', 'HATLASJ085750', '34968', 'HATLASJ085750.1+012807', 'HOT2_EI_CII_G09.v2.235', 'HOT2_EI_CII_G09.v2.60', 'HATLAS_J085753.1+012332', 'HATLAS_J085021.6+010503', 'HATLAS_J084532.7+011802', '6J090038.0+012810']
# --------------------------------
# This query took 0.0475869099299113 min.
# Querying 1896 galaxies took 0.20788390636444093 min.
# --------------------------------
# Number of projects = 15
# Number of observations = 17
# Number of unique subbands = 60
# Total number of subbands = 68
# 16 target(s) with ALMA data = ['2993', '1237654030328791126', 'C_488', '410490', 'HATLASJ091956.9+013852', 'Alpine_2', '13J090238.7+013253', '12J090234.3+012518', 'DEIMOS_COSMOS_460378', 'HATLAS_J092131.0+013432', 'J100217.9+015124', 'AzTECC51', 'AzTECC43', 'lowz_cell8_108065', 'AGC191728', 'HATLASJ091956']
# --------------------------------
# This query took 0.04861664374669393 min.
# Querying 1896 galaxies took 0.1927999536196391 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['Abell_611', 'GAMA417678', 'HOT2_EI_CII_G09.v2.232']
# --------------------------------
# This query took 0.03237525622049967 min.
# Querying 1896 galaxies took 0.18045432567596437 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 3
# Total number of subbands = 3
# 1 target(s) with ALMA data = ['J1016+0028']
# --------------------------------
# This query took 0.030440286795298258 min.
# Querying 1896 galaxies took 0.21636811892191568 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 8
# Number of unique subbands = 30
# Total number of subbands = 30
# 2 target(s) with ALMA data = ['IRAS_13509+0442', '12494']
# --------------------------------
# This query took 0.048156130313873294 min.
# Querying 1896 galaxies took 0.2103544314702352 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 6
# Number of unique subbands = 24
# Total number of subbands = 24
# 3 target(s) with ALMA data = ['AGC252580', 'HATLAS701', 'J1521+0420']
# --------------------------------
# This query took 0.03634224732716878 min.
# Querying 1896 galaxies took 0.17843681176503498 min.
# No matches!
# Querying 1896 galaxies took 0.18711881240208944 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 12
# Total number of subbands = 22
# 2 target(s) with ALMA data = ['0570_537_52266', 'S05']
# --------------------------------
# This query took 0.035863788922627766 min.
# Querying 1896 galaxies took 0.19555132786432902 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['653728']
# --------------------------------
# This query took 0.021933619181315103 min.
# Querying 1896 galaxies took 0.19773879448572795 min.
# No matches!
# Querying 1896 galaxies took 0.17335206270217896 min.
# No matches!
# Querying 1896 galaxies took 0.17033008734385172 min.
# No matches!
# Querying 1896 galaxies took 0.2722555200258891 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 12
# Total number of subbands = 16
# 4 target(s) with ALMA data = ['1237655495979106610', 'HATLAS1674', 'HATLAS1730', '263667']
# --------------------------------
# This query took 0.036242663860321045 min.
# Querying 1896 galaxies took 0.23269472122192383 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['VV847', '170103']
# --------------------------------
# This query took 0.028764601548512778 min.
# Querying 1896 galaxies took 0.19046488205591838 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['SDSS_J151834.67-013743.8', 'HATLAS_RED_2255']
# --------------------------------
# This query took 0.02737735112508138 min.
# Querying 1896 galaxies took 0.23024772802988688 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['19', 'PM2_7975_6104']
# --------------------------------
# This query took 0.029565234978993733 min.
# Querying 1896 galaxies took 0.2143692930539449 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 14
# Total number of subbands = 14
# 2 target(s) with ALMA data = ['UGC11958', 'Neptune']
# --------------------------------
# This query took 0.03181960185368856 min.
# Querying 1896 galaxies took 0.21952377160390218 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 24
# Total number of subbands = 28
# 3 target(s) with ALMA data = ['Neptune', 'C22-2', '16911']
# --------------------------------
# This query took 0.07341004610061645 min.
# Querying 1896 galaxies took 0.17389713128407797 min.
# No matches!
# Querying 1896 galaxies took 0.26602934996287025 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 25
# Total number of subbands = 28
# 5 target(s) with ALMA data = ['299299', '456147', 'GAMA496966', 'RXCJ1504.1-0248', 'APX_SB2_5']
# --------------------------------
# This query took 0.03723413546880086 min.
# Querying 1896 galaxies took 0.19636199474334717 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['29955']
# --------------------------------
# This query took 0.023870229721069336 min.
# Querying 1896 galaxies took 0.18910529216130575 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['NGC7194']
# --------------------------------
# This query took 0.023443798224131267 min.
# Querying 1896 galaxies took 0.21598872741063435 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['Neptune', 'dm2227-09']
# --------------------------------
# This query took 0.025104876359303793 min.
# Querying 1896 galaxies took 0.22042258183161417 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 11
# Number of unique subbands = 39
# Total number of subbands = 40
# 10 target(s) with ALMA data = ['RXJ2129.7+0005', '7964-1902', 'PM1_8615_1901', 'PM1_8623_1902', '587731173842027508_8623-6104', 'H04', '8615-9101', '8623-6104', 'SDSS_J211333.80-000950.4', 'SDSS_J211307.21+005108.5']
# --------------------------------
# This query took 0.04547212521235148 min.
# Querying 1896 galaxies took 0.2408473014831543 min.
# --------------------------------
# Number of projects = 11
# Number of observations = 18
# Number of unique subbands = 62
# Total number of subbands = 66
# 11 target(s) with ALMA data = ['SDSS_J2118+0017', '8655-3701', 'HELMS_RED_385', 'VV492', 'SDSSJ2118+0017', '8623-12702', '8616-1902', '8655-1902', 'ACT-S_J234648-000519', 'WP_8616_9101', 'cQSO_J220943.43-003338.7']
# --------------------------------
# This query took 0.05573028326034546 min.
# Querying 1896 galaxies took 0.23839964469273886 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 19
# Number of unique subbands = 64
# Total number of subbands = 72
# 16 target(s) with ALMA data = ['ADF22', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', 'NBJ-CFHT-C343', 'mADF22', 'Core_region', 'UGC01123', '8086-9101', 'PM2_8153_12702', 'CP_7968_12705', 'dm0052+00_I116', 'dm0052+00_I115', 'DSFG4', 'RXCJ2341.1+0018']
# --------------------------------
# This query took 0.14926376740137737 min.
# Querying 1896 galaxies took 0.2843865911165873 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 23
# Number of unique subbands = 86
# Total number of subbands = 93
# 7 target(s) with ALMA data = ['587731513694355564_8155-6102', '9io9', 'HERS1', 'hers1', 'PJ020941.3', '8081-9102', 'CP_8078_6104']
# --------------------------------
# This query took 0.0705470601717631 min.
# Querying 1896 galaxies took 0.16191515525182087 min.
# No matches!
# Querying 1896 galaxies took 0.16898985306421915 min.
# No matches!
# Querying 1896 galaxies took 0.18411245346069335 min.
# No matches!
# Querying 1896 galaxies took 0.2480816682179769 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 14
# Total number of subbands = 14
# 4 target(s) with ALMA data = ['SDSS_212639.87+001830.0', '1237657190888898714', '587731186187632690_8616-9102', '8616-6104']
# --------------------------------
# This query took 0.03531840642293294 min.
# Querying 1896 galaxies took 0.24614669481913248 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 8
# Number of unique subbands = 30
# Total number of subbands = 30
# 7 target(s) with ALMA data = ['Q01322-0051', 'RFGC296', '1237657070091960362', '8081-9101', '8080-3704', 'WP_8085_3704', '587731512617664623_8154-9102']
# --------------------------------
# This query took 0.041293688615163165 min.
# Querying 1896 galaxies took 0.18519816398620606 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 11
# Number of unique subbands = 29
# Total number of subbands = 37
# 8 target(s) with ALMA data = ['8081-12703', 'CP_8085_6101', 'S02', '587731512619696292_8084-3702', '0413_238_51929', '8081-6102', 'dm0346+00_I110', 'dm0346+00_I109']
# --------------------------------
# This query took 0.047254331906636554 min.
# Querying 1896 galaxies took 0.17326497236887614 min.
# No matches!
# Querying 1896 galaxies took 0.21938881079355876 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['IC_485', '8941-3701']
# --------------------------------
# This query took 0.026831388473510742 min.
# Querying 1896 galaxies took 0.1784135063489278 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['8149-12704']
# --------------------------------
# This query took 0.025881505012512206 min.
# Querying 1896 galaxies took 0.1706201473871867 min.
# No matches!
# Querying 1896 galaxies took 0.17335944573084514 min.
# No matches!
# Querying 1896 galaxies took 0.1717429796854655 min.
# No matches!
# Querying 1896 galaxies took 0.17786411046981812 min.
# No matches!
# Querying 1896 galaxies took 0.18705610036849976 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['J1057']
# --------------------------------
# This query took 0.023284526666005452 min.
# Querying 1896 galaxies took 0.21139998038609822 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['Ganymede', 'J092042.47+054412.3']
# --------------------------------
# This query took 0.06062527894973755 min.
# Querying 1896 galaxies took 0.1984025279680888 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 10
# Number of unique subbands = 40
# Total number of subbands = 40
# 4 target(s) with ALMA data = ['G244.8+54.9', 'PJ105353', 'J1053', 'PLCK_G244.8+54.9']
# --------------------------------
# This query took 0.06528486808141072 min.
# Querying 1896 galaxies took 0.18670189380645752 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 15
# Total number of subbands = 15
# 4 target(s) with ALMA data = ['Ganymede', 'IRAS_09039+0503', '445641', '318424']
# --------------------------------
# This query took 0.0431648850440979 min.
# Querying 1896 galaxies took 0.19163802067438762 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 7
# Number of unique subbands = 17
# Total number of subbands = 21
# 4 target(s) with ALMA data = ['J1108+0659', 'G08-5', 'dm0916+06_I040', 'dm0916+06_I039']
# --------------------------------
# This query took 0.057891786098480225 min.
# Querying 1896 galaxies took 0.16651129325230915 min.
# No matches!
# Querying 1896 galaxies took 0.16830138365427652 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['NGC_6264']
# --------------------------------
# This query took 0.025891550381978354 min.
# Querying 1896 galaxies took 0.15839963754018146 min.
# No matches!
# Querying 1896 galaxies took 0.21199366251627605 min.
# No matches!
# Querying 1896 galaxies took 0.18479929765065511 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['IRAS_F10173+0828']
# --------------------------------
# This query took 0.034879541397094725 min.
# Querying 1896 galaxies took 0.17985732555389405 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['530542']
# --------------------------------
# This query took 0.03512208064397176 min.
# Querying 1896 galaxies took 0.18952757517496746 min.
# No matches!
# Querying 1896 galaxies took 0.18129825194676716 min.
# No matches!
# Querying 1896 galaxies took 0.17637388706207274 min.
# No matches!
# Querying 1896 galaxies took 0.16378880739212037 min.
# No matches!
# Querying 1896 galaxies took 0.16301977634429932 min.
# No matches!
# Querying 1896 galaxies took 0.1847726027170817 min.
# No matches!
# Querying 1896 galaxies took 0.1875247597694397 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 9
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['0379_579_51789', 'S15']
# --------------------------------
# This query took 0.05007160107294718 min.
# Querying 1896 galaxies took 0.16940215826034546 min.
# No matches!
# Querying 1896 galaxies took 0.17717087666193646 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['RXJ0820.9+0752', 'IC_2810', '658645']
# --------------------------------
# This query took 0.0567160447438558 min.
# Querying 1896 galaxies took 0.18227068185806275 min.
# --------------------------------
# Number of projects = 14
# Number of observations = 36
# Number of unique subbands = 95
# Total number of subbands = 141
# 7 target(s) with ALMA data = ['NGC_4321', 'ngc4321', 'J0909+1052', 'SN2020oi', 'NGC4321', '373633', 'M100']
# --------------------------------
# This query took 0.14562516609827678 min.
# Querying 1896 galaxies took 0.1700905442237854 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 5
# Total number of subbands = 12
# 1 target(s) with ALMA data = ['NGC2859']
# --------------------------------
# This query took 0.02622995376586914 min.
# Querying 1896 galaxies took 0.16292506456375122 min.
# No matches!
# Querying 1896 galaxies took 0.17193642059961955 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['IC1079']
# --------------------------------
# This query took 0.02413514455159505 min.
# Querying 1896 galaxies took 0.1626521388689677 min.
# No matches!
# Querying 1896 galaxies took 0.18078224261601766 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['113989']
# --------------------------------
# This query took 0.023819891611735027 min.
# Querying 1896 galaxies took 0.17998119592666625 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['5511']
# --------------------------------
# This query took 0.025238521893819175 min.
# Querying 1896 galaxies took 0.18664729595184326 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 3
# Total number of subbands = 3
# 1 target(s) with ALMA data = ['J1055+1102']
# --------------------------------
# This query took 0.022928376992543537 min.
# Querying 1896 galaxies took 0.19292737245559693 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 17
# Total number of subbands = 20
# 2 target(s) with ALMA data = ['4C+29.30', 'SDSS_081958.64+262311.3']
# --------------------------------
# This query took 0.03604936599731445 min.
# Querying 1896 galaxies took 0.168629519144694 min.
# No matches!
# Querying 1896 galaxies took 0.17842361132303874 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 8
# Number of unique subbands = 32
# Total number of subbands = 32
# 4 target(s) with ALMA data = ['NGC_4419', 'Pallas', '640777', 'NGC4419']
# --------------------------------
# This query took 0.037627649307250974 min.
# Querying 1896 galaxies took 0.16112007300059 min.
# No matches!
# Querying 1896 galaxies took 0.17224164803822836 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['RXCJ1350.3+0940']
# --------------------------------
# This query took 0.025358064969380697 min.
# Querying 1896 galaxies took 0.16862666606903076 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['7987']
# --------------------------------
# This query took 0.022801498572031658 min.
# Querying 1896 galaxies took 0.16615189711252848 min.
# No matches!
# Querying 1896 galaxies took 0.18120379447937013 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['9088-9102']
# --------------------------------
# This query took 0.02349432309468587 min.
# Querying 1896 galaxies took 0.16597384611765545 min.
# No matches!
# Querying 1896 galaxies took 0.17944151163101196 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 17
# Total number of subbands = 21
# 4 target(s) with ALMA data = ['NGC_6106', 'J1430+1339', 'SDSS_J143029.88+133912.0', 'Teacup_AGN']
# --------------------------------
# This query took 0.033800999323527016 min.
# Querying 1896 galaxies took 0.16234898964564007 min.
# No matches!
# Querying 1896 galaxies took 0.17520355383555095 min.
# No matches!
# Querying 1896 galaxies took 0.17083695729573567 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 20
# Number of unique subbands = 62
# Total number of subbands = 82
# 3 target(s) with ALMA data = ['AT2018cow', '10993', 'AT2018cowATLAS18qqn']
# --------------------------------
# This query took 0.0681872288386027 min.
# Querying 1896 galaxies took 0.16406220197677612 min.
# No matches!
# Querying 1896 galaxies took 0.17145566940307616 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['IRAS_F13443+0802', '411612']
# --------------------------------
# This query took 0.02866542339324951 min.
# Querying 1896 galaxies took 0.17239961624145508 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 5
# 2 target(s) with ALMA data = ['AGC_8585', 'Q14550+0715']
# --------------------------------
# This query took 0.03269939025243123 min.
# Querying 1896 galaxies took 0.1689914345741272 min.
# No matches!
# Querying 1896 galaxies took 0.1636423110961914 min.
# No matches!
# Querying 1896 galaxies took 0.16693597237269084 min.
# No matches!
# Querying 1896 galaxies took 0.168459685643514 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 6
# Total number of subbands = 6
# 2 target(s) with ALMA data = ['7598', '321551']
# --------------------------------
# This query took 0.025879522164662678 min.
# Querying 1896 galaxies took 0.16948423385620118 min.
# No matches!
# Querying 1896 galaxies took 0.162501851717631 min.
# No matches!
# Querying 1896 galaxies took 0.21411374012629192 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 7
# Total number of subbands = 7
# 2 target(s) with ALMA data = ['IRAS_10190+1322', 'IRAS_F10190+1322']
# --------------------------------
# This query took 0.031188035011291505 min.
# Querying 1896 galaxies took 0.1780140519142151 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 4
# Number of unique subbands = 13
# Total number of subbands = 16
# 2 target(s) with ALMA data = ['NGC3596', '26634']
# --------------------------------
# This query took 0.03497950633366902 min.
# Querying 1896 galaxies took 0.18013424078623455 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 11
# Number of unique subbands = 28
# Total number of subbands = 42
# 8 target(s) with ALMA data = ['NGC_4254', '1994018546606172160', '656018', '577834', '437037', 'ngc4254_enuc001', 'ngc4254', 'DDO_155']
# --------------------------------
# This query took 0.04066226879755656 min.
# Querying 1896 galaxies took 0.16175090074539183 min.
# No matches!
# Querying 1896 galaxies took 0.18822962045669556 min.
# No matches!
# Querying 1896 galaxies took 0.15986231168111165 min.
# No matches!
# Querying 1896 galaxies took 0.15773000319798788 min.
# No matches!
# Querying 1896 galaxies took 0.17050766150156657 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['2408']
# --------------------------------
# This query took 0.023909318447113036 min.
# Querying 1896 galaxies took 0.16933763027191162 min.
# No matches!
# Querying 1896 galaxies took 0.1676600138346354 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['127995']
# --------------------------------
# This query took 0.02596776485443115 min.
# Querying 1896 galaxies took 0.17396801312764484 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['224444']
# --------------------------------
# This query took 0.027200182278951008 min.
# Querying 1896 galaxies took 0.1737824002901713 min.
# No matches!
# Querying 1896 galaxies took 0.18605894247690838 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['CIG234']
# --------------------------------
# This query took 0.028122496604919434 min.
# Querying 1896 galaxies took 0.20036107699076336 min.
# No matches!
# Querying 1896 galaxies took 0.19497350454330445 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['PGC57003']
# --------------------------------
# This query took 0.048025051752726235 min.
# Querying 1896 galaxies took 0.1642516851425171 min.
# No matches!
# Querying 1896 galaxies took 0.21191630363464356 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 2
# Total number of subbands = 2
# 2 target(s) with ALMA data = ['J132838.16+333618.3', 'J133306.57+330903.7']
# --------------------------------
# This query took 0.023411973317464193 min.
# Querying 1896 galaxies took 0.1723562439282735 min.
# No matches!
# Querying 1896 galaxies took 0.17750099102656047 min.
# No matches!
# Querying 1896 galaxies took 0.1740327795346578 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 5
# Number of unique subbands = 15
# Total number of subbands = 15
# 5 target(s) with ALMA data = ['8952-6104', 'J1220+2916', 'J133944.15+274635.2', 'PGC046123', '324315']
# --------------------------------
# This query took 0.03521757920583089 min.
# Querying 1896 galaxies took 0.16828063726425171 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['93078']
# --------------------------------
# This query took 0.023413360118865967 min.
# Querying 1896 galaxies took 0.18559299310048422 min.
# No matches!
# Querying 1896 galaxies took 0.1727224349975586 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['J1228+3706', 'HATLAS_RED_2098']
# --------------------------------
# This query took 0.02811575730641683 min.
# Querying 1896 galaxies took 0.17291084925333658 min.
# No matches!
# Querying 1896 galaxies took 0.18809418280919393 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['J0854+2006']
# --------------------------------
# This query took 0.02881691853205363 min.
# Querying 1896 galaxies took 0.16740959882736206 min.
# No matches!
# Querying 1896 galaxies took 0.16204049587249755 min.
# No matches!
# Querying 1896 galaxies took 0.17883598804473877 min.
# No matches!
# Querying 1896 galaxies took 0.17830559015274047 min.
# No matches!
# Querying 1896 galaxies took 0.19834461609522502 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 7
# Total number of subbands = 7
# 3 target(s) with ALMA data = ['8492', 'IRASF13182+3424', 'J132035.40+340821.7']
# --------------------------------
# This query took 0.032762539386749265 min.
# Querying 1896 galaxies took 0.168798025449117 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HATLAS_RED_2007']
# --------------------------------
# This query took 0.02484870751698812 min.
# Querying 1896 galaxies took 0.17679826418558756 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 12
# Total number of subbands = 21
# 3 target(s) with ALMA data = ['CIG501', 'J132443.68+323225.0', 'NGC4395']
# --------------------------------
# This query took 0.03949664036432902 min.
# Querying 1896 galaxies took 0.16694091161092123 min.
# No matches!
# Querying 1896 galaxies took 0.1734470009803772 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 6
# Total number of subbands = 6
# 2 target(s) with ALMA data = ['5456', 'SDSS_093507.06+261806.5']
# --------------------------------
# This query took 0.02652550538380941 min.
# Querying 1896 galaxies took 0.17028726736704508 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 1
# Total number of subbands = 1
# 1 target(s) with ALMA data = ['J131047.64+294235.6']
# --------------------------------
# This query took 0.02258986234664917 min.
# Querying 1896 galaxies took 0.16755282878875732 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['NGC_4922']
# --------------------------------
# This query took 0.02499833106994629 min.
# Querying 1896 galaxies took 0.16855420271555582 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['NGC6004', 'hs1549']
# --------------------------------
# This query took 0.05627981424331665 min.
# Querying 1896 galaxies took 0.1699521581331889 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 3
# Total number of subbands = 3
# 2 target(s) with ALMA data = ['8952-12701', 'J134017.95+262058.3']
# --------------------------------
# This query took 0.02614349126815796 min.
# Querying 1896 galaxies took 0.16817415555318196 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 21
# Number of unique subbands = 83
# Total number of subbands = 87
# 1 target(s) with ALMA data = ['J1606+1814']
# --------------------------------
# This query took 0.06287062962849935 min.
# Querying 1896 galaxies took 0.21329798301060995 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 3
# Total number of subbands = 3
# 1 target(s) with ALMA data = ['R02']
# --------------------------------
# This query took 0.021772555510203042 min.
# Querying 1896 galaxies took 0.44378727674484253 min.
# No matches!
# Querying 1896 galaxies took 0.44711349805196127 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['RXCJ1603.6+1553']
# --------------------------------
# This query took 0.03190059661865234 min.
# Querying 1896 galaxies took 0.26190617481867473 min.
# No matches!
# Querying 1896 galaxies took 0.2298664371172587 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 11
# Total number of subbands = 15
# 3 target(s) with ALMA data = ['CIG_268', 'R05', 'CP_8241_12705']
# --------------------------------
# This query took 0.030418999989827476 min.
# Querying 1896 galaxies took 0.24592500925064087 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['CIG494', '587741490891325518_8241-3704']
# --------------------------------
# This query took 0.038910154501597086 min.
# Querying 1896 galaxies took 0.17818811734517415 min.
# No matches!
# Querying 1896 galaxies took 0.19925808906555176 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['HATLAS_RED_2145', 'RFGC2966']
# --------------------------------
# This query took 0.02471324602762858 min.
# Querying 1896 galaxies took 0.2535968104998271 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['SDSS_144151.70+201401.8', 'J081107.38+164304.1']
# --------------------------------
# This query took 0.02540579636891683 min.
# Querying 1896 galaxies took 0.24032156070073446 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 5
# 2 target(s) with ALMA data = ['AGC_174522', 'J0832+1832']
# --------------------------------
# This query took 0.026078359285990397 min.
# Querying 1896 galaxies took 0.2707288702329 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 6
# Number of unique subbands = 18
# Total number of subbands = 24
# 4 target(s) with ALMA data = ['J112531.90+290311.3', '587741421099155681_8241-3703', '2276_444_53712', 'H01']
# --------------------------------
# This query took 0.04780311584472656 min.
# Querying 1896 galaxies took 0.2828133900960286 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['UGC04240']
# --------------------------------
# This query took 0.02246981064478556 min.
# Querying 1896 galaxies took 0.2351689338684082 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['NGC_4150', 'NGC2596']
# --------------------------------
# This query took 0.02710658311843872 min.
# Querying 1896 galaxies took 0.22691242297490438 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['587741533840670747_8241-6102']
# --------------------------------
# This query took 0.024802807966868082 min.
# Querying 1896 galaxies took 0.21508286794026693 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 5
# Number of unique subbands = 12
# Total number of subbands = 20
# 1 target(s) with ALMA data = ['NGC3504']
# --------------------------------
# ...
# Number of projects = 1
# Number of observations = 4
# Number of unique subbands = 12
# Total number of subbands = 16
# 4 target(s) with ALMA data = ['66351', '578499', '304615', '654650']
# --------------------------------
# This query took 0.035705045859018965 min.
# Querying 1896 galaxies took 0.18559981981913248 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['640213', '67202', '609961']
# --------------------------------
# This query took 0.03323520421981811 min.
# Querying 1896 galaxies took 0.17621569633483886 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['PGC_043234']
# --------------------------------
# This query took 0.02227886120478312 min.
# Querying 1896 galaxies took 0.1799938956896464 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 6
# Number of unique subbands = 28
# Total number of subbands = 28
# 2 target(s) with ALMA data = ['Callisto', 'MOO_J0903+1310']
# --------------------------------
# This query took 0.03910362720489502 min.
# Querying 1896 galaxies took 0.16778316100438437 min.
# No matches!
# Querying 1896 galaxies took 0.18311004638671874 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['HATLAS1056', 'HATLAS400', 'HATLASJ115141.3-004240']
# --------------------------------
# This query took 0.036921401818593345 min.
# Querying 1896 galaxies took 0.18841125965118408 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 9
# Number of unique subbands = 32
# Total number of subbands = 36
# 9 target(s) with ALMA data = ['1237674651535867994', 'HATLAS863', 'HATLAS331', 'HATLAS1018', 'Zwicky_3146', 'zwicky_3146', 'zw_3146', '122117', '168778']
# --------------------------------
# This query took 0.041476086775461836 min.
# Querying 1896 galaxies took 0.21265486478805543 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 4
# 2 target(s) with ALMA data = ['rs0107', 'rs0105']
# --------------------------------
# This query took 0.024441929658253987 min.
# Querying 1896 galaxies took 0.23447848161061605 min.
# No matches!
# Querying 1896 galaxies took 0.1706416090329488 min.
# No matches!
# Querying 1896 galaxies took 0.2051168441772461 min.
# No matches!
# Querying 1896 galaxies took 0.23510682582855225 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['1237655124470661181', '246603', '14265']
# --------------------------------
# This query took 0.03190581401189168 min.
# Querying 1896 galaxies took 0.20389443635940552 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 8
# Number of unique subbands = 31
# Total number of subbands = 31
# 3 target(s) with ALMA data = ['IRAS_08572+3915', 'IRAS 08572+3915', '239192']
# --------------------------------
# This query took 0.036824425061543785 min.
# Querying 1896 galaxies took 0.19899152914683024 min.
# --------------------------------
# Number of projects = 9
# Number of observations = 13
# Number of unique subbands = 49
# Total number of subbands = 49
# 6 target(s) with ALMA data = ['IRAS_08572+3915', 'IRAS 08572+3915', '8655-12705', 'PKS0034-01', '3C15', 'J0029-0113']
# --------------------------------
# This query took 0.05045957962671916 min.
# Querying 1896 galaxies took 0.22187837362289428 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 20
# Total number of subbands = 20
# 5 target(s) with ALMA data = ['HCG25b', '8086-3704', '588015508213989555_8077-6104', '8155-6101', '8084-12705']
# --------------------------------
# This query took 0.04144837458928426 min.
# Querying 1896 galaxies took 0.2828081488609314 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['588015510364880957_8082-6103', 'SDSS_074755.45+192910.5']
# --------------------------------
# This query took 0.02956814765930176 min.
# Querying 1896 galaxies took 0.19058693250020345 min.
# No matches!
# Querying 1896 galaxies took 0.17542359034220378 min.
# No matches!
# Querying 1896 galaxies took 0.17961314519246419 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['NGC_4189']
# --------------------------------
# This query took 0.030988089243570962 min.
# Querying 1896 galaxies took 0.17802047332127888 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['11014']
# --------------------------------
# This query took 0.023921974500020347 min.
# Querying 1896 galaxies took 0.16565237442652384 min.
# No matches!
# Querying 1896 galaxies took 0.23127748171488444 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 8
# Number of unique subbands = 23
# Total number of subbands = 30
# 7 target(s) with ALMA data = ['1237663783669334090', '1237663783663960074', '588015508731723912_8655-9102', '8082-12704', 'dm0027+00_I097', 'dm0027+00_I098', 'Cosmic_skidmark']
# --------------------------------
# This query took 0.03992749849955241 min.
# Querying 1896 galaxies took 0.2582028826077779 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 9
# Number of unique subbands = 30
# Total number of subbands = 34
# 9 target(s) with ALMA data = ['1237663784210464777', '8083-12703', '8085-6104', '8081-3702', '9194-3702', 'PM1_9194_3702', 'WP_8083_12703', '8084-6103', 'SMM_J030277']
# --------------------------------
# This query took 0.045384844144185386 min.
# Querying 1896 galaxies took 0.20122762521107992 min.
# No matches!
# Querying 1896 galaxies took 0.16311665773391723 min.
# No matches!
# Querying 1896 galaxies took 0.1738167365392049 min.
# No matches!
# Querying 1896 galaxies took 0.16902546485265096 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['474401']
# --------------------------------
# This query took 0.022599164644877115 min.
# Querying 1896 galaxies took 0.16367250283559162 min.
# No matches!
# Querying 1896 galaxies took 0.1612784783045451 min.
# No matches!
# Querying 1896 galaxies took 0.1655909498532613 min.
# No matches!
# Querying 1896 galaxies took 0.16624253193537394 min.
# No matches!
# Querying 1896 galaxies took 0.18119608561197917 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 5
# 2 target(s) with ALMA data = ['AGC_5737', '624421']
# --------------------------------
# This query took 0.034506444136301676 min.
# Querying 1896 galaxies took 0.18271579345067343 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 21
# Number of unique subbands = 65
# Total number of subbands = 79
# 8 target(s) with ALMA data = ['NGC_3351', '3C296', 'PGC214240', 'AGC_9162', 'NGC3351', 'M95', '3C_296', '3856']
# --------------------------------
# This query took 0.05315984487533569 min.
# Querying 1896 galaxies took 0.18005361954371135 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 7
# Number of unique subbands = 16
# Total number of subbands = 24
# 6 target(s) with ALMA data = ['NGC_4216', 'AGC_6206', 'IRAS_11506+1331', '68973', '475128', '272690']
# --------------------------------
# This query took 0.03751585086186727 min.
# Querying 1896 galaxies took 0.17910379966100057 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['355825']
# --------------------------------
# This query took 0.03174405097961426 min.
# Querying 1896 galaxies took 0.18198846181233724 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 8
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['NGC_4698', '123106']
# --------------------------------
# This query took 0.03891686598459879 min.
# Querying 1896 galaxies took 0.1751265048980713 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['NGC_4698']
# --------------------------------
# This query took 0.031507047017415364 min.
# Querying 1896 galaxies took 0.17974395751953126 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 8
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['SMG_8', 'NGC_4299']
# --------------------------------
# This query took 0.03189764022827148 min.
# Querying 1896 galaxies took 0.1853640874226888 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 13
# Total number of subbands = 13
# 3 target(s) with ALMA data = ['IRAS_10378+1109', 'IRAS_10378+1108', '232409']
# --------------------------------
# This query took 0.033317311604817705 min.
# Querying 1896 galaxies took 0.17874173323313394 min.
# No matches!
# Querying 1896 galaxies took 0.1767863353093465 min.
# No matches!
# Querying 1896 galaxies took 0.18632709582646687 min.
# No matches!
# Querying 1896 galaxies took 0.1726379911104838 min.
# No matches!
# Querying 1896 galaxies took 0.1654007315635681 min.
# No matches!
# Querying 1896 galaxies took 0.17613625129063923 min.
# No matches!
# Querying 1896 galaxies took 0.16555659770965575 min.
# No matches!
# Querying 1896 galaxies took 0.16269258658091226 min.
# No matches!
# Querying 1896 galaxies took 0.162748122215271 min.
# No matches!
# Querying 1896 galaxies took 0.17182182073593139 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 18
# Number of unique subbands = 36
# Total number of subbands = 72
# 4 target(s) with ALMA data = ['NGC5248', 'NGC_5248', '618039', '189167']
# --------------------------------
# This query took 0.049717950820922854 min.
# Querying 1896 galaxies took 0.17257219950358074 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['308811']
# --------------------------------
# This query took 0.02616827090581258 min.
# Querying 1896 galaxies took 0.16511497497558594 min.
# No matches!
# Querying 1896 galaxies took 0.1706297000249227 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 7
# Number of unique subbands = 27
# Total number of subbands = 27
# 2 target(s) with ALMA data = ['SDSS_164922.21+264710.5', 'IRAS_15250+3609']
# --------------------------------
# This query took 0.0642220695813497 min.
# Querying 1896 galaxies took 0.18249768416086834 min.
# No matches!
# Querying 1896 galaxies took 0.19301423629124959 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 19
# Total number of subbands = 27
# 3 target(s) with ALMA data = ['NGC3626', '2360_167_53728', 'H02']
# --------------------------------
# This query took 0.04410595099131266 min.
# Querying 1896 galaxies took 0.16987550656000774 min.
# No matches!
# Querying 1896 galaxies took 0.17630091110865276 min.
# No matches!
# Querying 1896 galaxies took 0.19122567971547444 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 13
# Number of unique subbands = 32
# Total number of subbands = 52
# 12 target(s) with ALMA data = ['HATLAS1063', 'HATLAS788', 'HATLAS965', 'HATLAS861', 'HATLAS794', 'HATLASJ115317.4-010123', 'HATLASJ121908.7-010159', 'JO204_CO10', 'JO204_CO21', '114808', 'HATLASJ121908', 'HATLASJ115317']
# --------------------------------
# This query took 0.046959765752156574 min.
# Querying 1896 galaxies took 0.22678163448969524 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 21
# Number of unique subbands = 75
# Total number of subbands = 81
# 13 target(s) with ALMA data = ['2J091448.7-003533', 'SN_2015bn', '527928', 'GAMA574200', 'APEX_SB11', 'APEX_SB15', 'HerBS-100', 'SN2015bn', '9J090952.3-003019', 'HATLAS_J092614.4-000744', 'HATLAS_J090940.8-002757', 'J090655.44-000152.7', 'HATLAS752']
# --------------------------------
# This query took 0.0629399577776591 min.
# Querying 1896 galaxies took 0.2563625931739807 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 9
# Number of unique subbands = 30
# Total number of subbands = 30
# 5 target(s) with ALMA data = ['HATLAS_J143430.9+004133', 'HATLAS852', 'HATLAS1661', 'HATLAS680', 'G14-1']
# --------------------------------
# This query took 0.041905816396077475 min.
# Querying 1896 galaxies took 0.17325592438379925 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 4
# Number of unique subbands = 6
# Total number of subbands = 14
# 4 target(s) with ALMA data = ['631801', '620714', '408880', '2322']
# --------------------------------
# This query took 0.036121173699696855 min.
# Querying 1896 galaxies took 0.18743304014205933 min.
# No matches!
# Querying 1896 galaxies took 0.15163787603378295 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['PGC57475']
# --------------------------------
# This query took 0.0295215646425883 min.
# Querying 1896 galaxies took 0.2082728624343872 min.
# No matches!
# Querying 1896 galaxies took 0.18040682872136435 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 9
# Number of unique subbands = 28
# Total number of subbands = 35
# 5 target(s) with ALMA data = ['UGC_06697', '2MASX_J11443212+2006238', 'KUG_1141+204', 'KUG1140+202B', 'J1114+1939']
# --------------------------------
# This query took 0.03914533853530884 min.
# Querying 1896 galaxies took 0.17313154538472494 min.
# No matches!
# Querying 1896 galaxies took 0.16113785902659097 min.
# No matches!
# Querying 1896 galaxies took 0.2718015948931376 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 12
# Number of unique subbands = 46
# Total number of subbands = 46
# 11 target(s) with ALMA data = ['HATLAS_J142559.2-003552', '1237648720684449913', 'HATLAS879', 'HATLAS340', 'HATLAS_RED_1190', 'GAMA570227', 'GAMA567624', 'D15-3', 'CGCG013-092', 'APEX_SB13', 'APEX_SB31']
# --------------------------------
# This query took 0.05080604553222656 min.
# Querying 1896 galaxies took 0.2642875790596008 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 19
# Number of unique subbands = 63
# Total number of subbands = 75
# 15 target(s) with ALMA data = ['HATLAS_J142416.7-000218', 'SDSS_J115130.95-000439.9', 'GAMA593680', '244217', 'UGC9299', 'HOT2_EI_CII_G09.v2.45', 'HOT2_EI_CII_G09.v2.170', 'J1222-0007', 'SN2002ao', 'PM1_9512_3704', 'G09.v2.45', 'HATLAS1750', 'HATLAS1714', 'ugc9299', 'HATLAS808']
# --------------------------------
# This query took 0.05717637538909912 min.
# Querying 1896 galaxies took 0.23027904431025187 min.
# --------------------------------
# Number of projects = 28
# Number of observations = 44
# Number of unique subbands = 146
# Total number of subbands = 151
# 14 target(s) with ALMA data = ['J1516+0015', '1237648721763827882', 'J1133+0015', '645479', 'GAMA619098', 'GAMA618906', 'GAMA618935', '65228', 'HOT2_EI_CII_G09.v2.48', 'HOT2_EI_CII_G09.v2.80', '3J085828.5+003814', 'HATLAS968', 'G09.v2.48', 'GAMA622429']
# --------------------------------
# This query took 0.11806315183639526 min.

# %%
# concatenate queries from Jobs

files = glob.glob('/arc/projects/salvage/ALMAxmatch/ALminer_output/*Nov14*')

myquery_list = []
for f in tqdm(files):
    myquery_list.append(pandas.read_pickle(f))
    
myquery = pandas.concat(myquery_list)

myquery.to_pickle(f'/arc/projects/salvage/ALMAxmatch/ALminer_output/SDSS-ALMA-search-Nov14-total.pkl')
# Out:
# 100%|██████████| 196/196 [00:12<00:00, 15.16it/s]

# %%
alminer.summary(myquery)
# Out:
# --------------------------------
# Number of projects = 344
# Number of observations = 1333
# Number of unique subbands = 3170
# Total number of subbands = 5196
# 783 target(s) with ALMA data = ['HATLAS_RED_2145', 'RFGC2966', 'J1016+0028', 'Mrk_463', 'AGC_9727', 'J1518+1403', '588015510364880957_8082-6103', 'SDSS_074755.45+192910.5', '8149-12704', 'CIG_268', 'R05', 'CP_8241_12705', 'ADF22', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703
 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167', 'Q09498+0155', 'GEMS-N4636-18', 'Ceres', 'UGC07824', 'G09.v2.167', 'G09.v2.137', '0379_579_51789', 'S15', 'NGC_4419', 'Pallas', '640777', 'NGC4419', '1237663783669334090', '1237663783663960074', '588015508731723912_8655-9102', '8082-12704', 'dm0027+00_I097', 'dm0027+00_I098', 'Cosmic_skidmark', 'AGC242091', 'AGC242147', 'SDSS_J150904.22+043441.8', 'UGC_06697', 'KUG1141+200', '2MASX_J11434983+1958343', 'NGC_3859', 'KUG_1140+202A', '33288', '124350', 'NGC_6106', 'J1430+1339', 'SDSS_J143029.88+133912.0', 'Teacup_AGN', '640213', '67202', '609961', 'SDSS_J152224.73-004404.5', '105386', 'HATLASJ121253.5-002203', 'HATLASJ121253', 'J1606+1814', '239192', 'AGC_174522', 'J0832+1832', 'IC1079', 'PGC_043234', 'CGCG429-012', 'A1835', 'Abell 1835', '10828', '2MASX_J13441569+1933596', 'CIG501', 'J132443.68+323225.0', 'NGC4395', 'NGC_4922', 'HATLAS_RED_1830', 'J132051.75+312159.8', 'UGC11958', 'Neptune', 'SDSS_212639.87+001830.0', '1237657190888898714', '587731186187632690_8616-9102', '8616-6104', 'NGC_4321', 'ngc4321', 'J0909+1052 ...
# --------------------------------

# %%
alminer.plot_overview(myquery)

# %% [markdown]
# ## Match myquery catalog back to SDSS RA/Dec to get redshifts for each observation

# %%
ra_query, dec_query = np.array(myquery['RAJ2000']), np.array(myquery['DEJ2000'])

# %%
objID_query = []
z_query = []
mass_query = []

for ra_q, dec_q in zip(ra_query, dec_query):
    
    diff = np.sqrt((ra_sdss-ra_q)**2 + (dec_sdss-dec_q)**2)
    
    if np.min(diff) > 30:
        print('Poor match!')
    
    objID_query.append(table_id[diff == np.min(diff)][0])
    z_query.append(z_sdss[diff == np.min(diff)][0])
    mass_query.append(mass_sdss[diff == np.min(diff)][0])

z_query = np.array(z_query)
mass_query = np.array(mass_query)

# %% [markdown]
# In the future I can replace the spatial_scale_max with an SDSS radius...

# %%
rf_12CO_10 = 115.27120180 #GHz

redshifted_line = rf_12CO_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 45
# Number of observations = 303
# Number of unique subbands = 188
# Total number of subbands = 312
# 294 target(s) with ALMA data = ['RFGC2966', 'AGC_9727', '588015510364880957_8082-6103', '8149-12704', 'CIG_268', 'CP_8241_12705', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', '8086-9101', 'PM2_8153_12702', 'CP_7968_12705', 'AGC_5737', '624421', '29955', 'HATLAS_J141235.5+023130', 'HATLAS_J145019.0+015206', 'HATLAS_J144244.2+015846', 'rs0680', 'rs0677', 'rs0679', 'RXCJ1350.3+0940', '587741421099155681_8241-3703', '8655-12705', 'PKS0034-01', '170103', '618039', '189167', '8655-3701', 'HELMS_RED_385', '8623-12702', '8616-1902', '8655-1902', 'WP_8616_9101', '4579', 'Q01322-0051', 'RFGC296', '8080-3704', 'WP_8085_3704', '8081-9101', '587731512617664623_8154-9102', '5511', 'GAMA417678', 'HOT2_EI_CII_G09.v2.232', 'CIG234', '127995', 'COSMOS-1200839', 'COSMOS-0969208', 'COSMOS-1197519', '265143', 'HOT2_EI_CII_G09.v2.58', 'HOT2_EI_CII_G09.v2.38', 'HOT2_EI_CII_G09.v2.77', 'COSMOSVLA3_225', '26634', '9658', '8952-12701', 'HATLAS_J143601.6+022933', 'J1303+2433', 'RFGC3069', '8950-12705', 'HATLAS_J084552.0+011121', 'HOT2_EI_CII_G09.v2.137', 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167
(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# No observations found.
# --------------------------------
# --------------------------------
# Number of projects = 21
# Number of observations = 46
# Number of unique subbands = 43
# Total number of subbands = 48
# 44 target(s) with ALMA data = ['IRAS_F12112+0305', 'irasf12112+0305', 'G08-5', 'G09.v2.77', 'H03', 'G09.v2.167', 'G09.v2.137', 'Teacup_AGN', 'HATLASJ121253', 'Abell 1835', 'RXCJ1504.1-0248', 'J1516+0015', 'G09.v2.48', 'HATLASJ091956', 'G09.v2.42', 'IRASF01364-1042', 'IRAS01364-1042', 'J1512+0203', 'G09.v2.107', 'HATLASJ085616', 'G04-1', 'NGC3351', 'G09.v2.52', 'G09.v2.26', 'HATLASJ142057', 'HATLASJ091157', 'G09.v2.103', '210358', 'HATLASJ121908', 'HATLASJ115317', 'IRAS_10378+1109', 'G14-1', 'G09.v2.235', 'SHOC_391', '021348', 'HATLASJ090223', 'G09.v2.55', 'CGCG436-030', 'S02', 'UGC9299', 'G09.v2.45', '015028', 'RXJ0820.9+0752', 'H02']
# --------------------------------

# %%
rf_13CO_21 = 220.3987 # 13CO J=2-1
redshifted_line = rf_13CO_21/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 1
# Total number of subbands = 1
# 1 target(s) with ALMA data = ['NGC_3351']
# --------------------------------
# --------------------------------
# Number of projects = 8
# Number of observations = 18
# Number of unique subbands = 14
# Total number of subbands = 21
# 13 target(s) with ALMA data = ['UGC01123', 'APEX_SB14', 'IRAS_F12112+0305', 'IRAS10565+2448', 'NGC_4419', 'NGC4321', 'NGC_4321', 'NGC_4299', 'NGC_3351', 'NGC_4698', 'NGC_4189', 'NGC_4216', 'NGC_4383']
# --------------------------------

# %%
rf_CI_10 = 492.1607 # [CI] P=1-0
redshifted_line = rf_CI_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 1
# Total number of subbands = 1
# 1 target(s) with ALMA data = ['NGC4321']
# --------------------------------
# --------------------------------
# Number of projects = 4
# Number of observations = 17
# Number of unique subbands = 14
# Total number of subbands = 17
# 13 target(s) with ALMA data = ['HATLAS_J141235.5+023130', 'HATLAS_J145019.0+015206', 'HATLAS_J143601.6+022933', 'ngc4321', 'NGC4321', 'J1516+0015', 'HATLAS_J144652.0+014010', 'HATLAS_J145013.2+012125', 'HATLAS_J142559.2-003552', 'HATLAS_J143430.9+004133', 'HATLAS_J140608.2+005501', 'HATLAS_J143336.7+005042', 'HATLAS_J142416.7-000218']
# --------------------------------

# %% [markdown]
# ## Properties of CO(1-0) matches

# %%
rf_12CO_10 = 115.27120180 #GHz
redshifted_line = rf_12CO_10/(1+z_query)

obs_mask = [(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]

# %%
obs_mask
# Out:
# [0    False
#  1    False
#  2    False
#  3    False
#  4     True
#       ...
#  3     True
#  4    False
#  5    False
#  6     True
#  7    False
#  Length: 5196, dtype: bool]

# %%
plt.figure(figsize = (9,5))
plt.hist(z_query[obs_mask[0]], bins = 50)
plt.title('Redshift distribution of CO(1-0) observations in SDSS')
plt.xlabel('Redshift')
plt.ylabel('Counts')
plt.show()

plt.figure(figsize = (9,5))
plt.hist(mass_query[obs_mask[0]], bins = 50)
plt.title('Stellar mass distribution of CO(1-0) observations in SDSS')
plt.xlabel('Total Stellar Mass')
plt.ylabel('Counts')
plt.show()

plt.figure(figsize = (9,5))
plt.scatter(z_query[obs_mask[0]], mass_query[obs_mask[0]])
plt.ylabel('Total Stellar Mass')
plt.xlabel('Redshift')
plt.show()
