# %%
! pip install alminer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached alminer-0.1.3-py3-none-any.whl (20 kB)
# ...
#   Using cached pyvo-1.2.1-py3-none-any.whl (832 kB)
# ...

# %%
import alminer
import pandas

# %%
#49.82143689 -0.96964645 (good ALMaQUEST galaxy)

# %%
#42.46662204 -0.07121246 (troubling ALMaQUEST galaxy)

# %%
myquery = alminer.conesearch(ra=42.46662204, dec=-0.07121246, point=False, search_radius=3, print_query=True)
# Out:
# Your query is: SELECT * FROM ivoa.ObsCore WHERE (1 = INTERSECTS(CIRCLE('ICRS',42.46662204,-0.07121246,0.05), s_region) OR 1 = CONTAINS(POINT('ICRS',42.46662204,-0.07121246), s_region)) AND data_rights LIKE '%Public%'
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['8078-6103']
# --------------------------------

# %%
myquery = alminer.run_query(query_str)

# %%
myquery = alminer.conesearch(ra=49.82143689, dec=-0.96964645, point=False, search_radius=0.5)
# Out:
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['587731511545626673_8081-3704']
# --------------------------------

# %%
myquery = alminer.conesearch(ra=323.40752218, dec=1.07095399, point=False, search_radius=0.5)
# Out:
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['CP_7968_12705']
# --------------------------------

# %%
myquery
# Out:
#    Obs    project_code              ALMA_source_name    RAJ2000   DEJ2000  \
# 0    1  2018.1.00541.S  587731511545626673_8081-3704  49.821442 -0.969631
# 1    2  2018.1.00541.S  587731511545626673_8081-3704  49.821442 -0.969631
# 2    3  2018.1.00541.S  587731511545626673_8081-3704  49.821442 -0.969631
# 3    4  2018.1.00541.S  587731511545626673_8081-3704  49.821442 -0.969631
#
#    ang_res_arcsec  min_freq_GHz  max_freq_GHz  central_freq_GHz  \
# 0           1.616        106.71        108.69            107.70
# 1           1.616         96.46         98.44             97.45
# 2           1.616         94.56         96.55             95.56
# 3           1.616        108.44        110.31            109.38
#
#    bandwidth_GHz  ...  type  scan_intent  science_observation  \
# 0          1.985  ...     S       TARGET                    T
# 1          1.985  ...     S       TARGET                    T
# 2          1.985  ...     S       TARGET                    T
# ...

# %%
import pymysql
import numpy as np

#Query MySQL for mock survey statmorph results
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 9 AND u.z_spec < 0.2 AND u.decl < 47'
x = 'SELECT DISTINCT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u, dr15_ALMA_spaxels a WHERE u.objID = a.objID AND u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 AND u.ra > 20 and u.ra < 35'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
table_id[ra_sdss == 42.46662204]
# Out:
# array(['587731512616157277'], dtype='<U18')

# %%
len(ra_sdss)
# Out:
# 51

# %%
(568753-513968)/568753
# Out:
# 0.09632476663859356

# %%
print(ra_sdss[5],dec_sdss[5])
# Out:
# 323.40752218 1.07095399

# %%
len(ra_sdss)
# Out:
# 568753

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
mycat =  {"Name": table_id,
          "RAJ2000" : ra_sdss,
          "DEJ2000" : dec_sdss,
           "z": z_sdss}

mycat = pandas.DataFrame(mycat)

myquery = alminer.catalog(mycat, search_radius = 3)
# Out:
# ...
# alminer.catalog results
# ...
# Target = 587731511545626673
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['587731511545626673_8081-3704']
# --------------------------------
# Target = 588015510364880957
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['588015510364880957_8082-6103']
# --------------------------------
# Target = 588015509828075649
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['WP_8083_12703', '8083-12703']
# --------------------------------
# Target = 588015507657719904
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# ...

# %%
np.unique(np.array(myquery["ALMA_source_name"]))
# Out:
# array(['1237657190888898714', '587727221402042402_7977-3703',
#        '587731173842027508_8623-6104', '587731186187632690_8616-9102',
#        '587731187797393472_8615-3703', '587731511545233578_8082-12701',
#        '587731511545626673_8081-3704', '587731512619696292_8084-3702',
#        '587731513694355564_8155-6102', '587741421099155681_8241-3703',
#        '587741490891325518_8241-3704', '587742060530696249_8450-6102',
#        '588015508213989555_8077-6104', '588015508731723912_8655-9102',
#        '588015510364880957_8082-6103', '7815-12705', '8077-9101',
#        '8081-12703', '8081-6102', '8081-9101', '8083-12703', '8084-12705',
#        '8084-6103', '8086-9101', '8155-6101', '8615-9101', '8616-6104',
#        '8618-9102', '8623-12702', '8623-6104', '8655-12705', '8655-3701',
#        '8728-3701', '8950-12705', '8952-12701', '8952-6104', '9194-3702',
#        'CP_7968_12705', 'CP_8078_6104', 'CP_8241_12705', 'CP_9195_9101',
# ...

# %%
alminer.summary(myquery)
# Out:
# --------------------------------
# Number of projects = 10
# Number of observations = 61
# Number of unique subbands = 190
# Total number of subbands = 199
# ...

# %%
alminer.plot_overview(myquery)

# %%
alminer.plot_line_overview(myquery, line_freq = 115.27120180, z = 0.05)

# %%
rf_12CO_10 = 115.27120180
z_min = 0.
z_max = 0.5
selected = myquery[(myquery["min_freq_GHz"] > rf_12CO_10/(1+z_max)) &
                   (myquery["max_freq_GHz"] < rf_12CO_10/(1+z_min)) &
                   (myquery["ang_res_arcsec"] < 3)]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 7
# Number of observations = 57
# Number of unique subbands = 179
# Total number of subbands = 186
# ...

# %%
ra_sdss
# Out:
# array([ 49.82143689,  49.78215908,  49.92932926, 357.65176944,
#        322.98051569, 323.40752218, 126.46116245,  47.0294424 ,
#        319.91975399, 322.90884307,  49.94013207,  50.63658867,
#         42.46662204, 318.99043808,  47.7721595 , 312.02361024,
#        310.21701687, 320.82655503,  50.39146198,  42.56064266,
#        319.27145783,  51.02711718,  42.03277806, 333.05203457,
#        204.93395984, 127.63198907,  51.15551055,  52.62136726,
#         50.74164625, 356.75181707,  28.07921485, 311.78094669,
#        126.56889413, 194.73318076,  42.73942039, 358.22185487,
#        322.7494346 ,  48.89644156,  53.81411231,  27.84278643,
#        332.79873079, 138.15123729,  57.24298571,  29.05220916,
#        204.68382396, 171.74883903, 321.07217669,  57.69904137,
#        324.89156234,  40.30388682,  41.64309665])

# %%
alminer.CO_lines(myquery, z=z_sdss, print_targets=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1320/2350480025.py in <module>
# ----> 1 alminer.CO_lines(myquery, z=z_sdss, print_targets=False)
#
# ~/.local/lib/python3.7/site-packages/alminer/alminer.py in CO_lines(observations, z, print_summary, print_targets)
#     771     for t, line in enumerate(CO_line_names):
#     772         line_df = line_coverage(observations, line_freq=CO_line_freq[line], z=z,
# --> 773                                 line_name=CO_line_names[t], print_summary=print_summary, print_targets=print_targets)
#     774         if not line_df.empty:
#     775             CO_df_list.append(line_df)
#
# ~/.local/lib/python3.7/site-packages/alminer/alminer.py in line_coverage(observations, line_freq, z, line_name, print_summary, print_targets)
#     731     # shift the line by redshift
# ...

# %%
import pymysql
import numpy as np

#Query MySQL for mock survey statmorph results
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 LIMIT 5000'
#x = 'SELECT DISTINCT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u, dr15_ALMA_spaxels a WHERE u.objID = a.objID AND u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 AND u.ra > 20 and u.ra < 35'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
import time

# %%
mycat =  {"Name": table_id,
          "RAJ2000" : ra_sdss,
          "DEJ2000" : dec_sdss,
           "z": z_sdss}

mycat = pandas.DataFrame(mycat)

start = time.time()
myquery = alminer.catalog(mycat, search_radius = 0.5)
end = time.time()
print(f'Querying {len(mycat)} galaxies took {(start-end)/60} min.')
# Out:
# ...
# alminer.catalog results
# ...
# Target = 587722953304310243
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304310184
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304310091
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304179134
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304179097
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304179083
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304179044
# --------------------------------
# No observations found.
# --------------------------------
# Target = 587722953304113519
# --------------------------------
# No observations found.
# ...

# %%
alminer.summary(myquery)
# Out:
# --------------------------------
# Number of projects = 15
# Number of observations = 33
# Number of unique subbands = 102
# Total number of subbands = 152
# 27 target(s) with ALMA data = ['FJ122021.84-010827.1', 'Callisto', 'HATLAS_RED_1178', 'HATLAS1713', '105386', 'SDSS_J152224.73-004404.5', 'HATLASJ121253.5-002203', 'HATLASJ121253', 'HATLAS740', '1237648704051675158', 'HATLAS1744', 'HATLAS_RED_2207', 'HATLAS_RED_2221', 'UR7G', 'HATLAS_RED_2348', 'GAMA64646', 'HATLASJ121427.3+005819', 'HATLAS1114', 'HATLAS_J140608.2+005501', 'HATLAS1745', '1237648705664450617', 'GAMA106389', 'HATLAS_RED_2299', 'HATLAS_J143336.7+005042', 'HATLAS_RED_2428', '015028', 'PM1_9195_3702']
# --------------------------------

# %%
alminer.plot_overview(myquery)

# %%
rf_12CO_10 = 115.27120180 #GHz
z_min = 0.
z_max = 0.5
selected = myquery[(myquery["min_freq_GHz"] > rf_12CO_10/(1+z_max)) & 
                   (myquery["max_freq_GHz"] < rf_12CO_10/(1+z_min)) &
                   (myquery["ang_res_arcsec"] < 3)]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 40
# Total number of subbands = 68
# 8 target(s) with ALMA data = ['105386', 'HATLASJ121253.5-002203', 'UR7G', 'HATLASJ121427.3+005819', 'HATLAS_J140608.2+005501', 'GAMA106389', 'HATLAS_J143336.7+005042', 'PM1_9195_3702']
# --------------------------------

# %%
rf_12CO_10 = 115.27120180 #GHz
z_min = 0.
z_max = 0.5
selected = myquery[(myquery["min_freq_GHz"] > rf_12CO_10/(1+z_max)) & 
                   (myquery["max_freq_GHz"] < rf_12CO_10/(1+z_min)) &
                   (myquery["ang_res_arcsec"] < 3) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe'))]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 40
# Total number of subbands = 68
# 8 target(s) with ALMA data = ['105386', 'HATLASJ121253.5-002203', 'UR7G', 'HATLASJ121427.3+005819', 'HATLAS_J140608.2+005501', 'GAMA106389', 'HATLAS_J143336.7+005042', 'PM1_9195_3702']
# --------------------------------

# %%
rf_12CO_10 = 115.27120180 #GHz
z_min = 0.
z_max = 0.5
selected = myquery[(myquery["min_freq_GHz"] > rf_12CO_10/(1+z_max)) & 
                   (myquery["max_freq_GHz"] < rf_12CO_10/(1+z_min)) &
                   (myquery["ang_res_arcsec"] < 3) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 29
# Total number of subbands = 54
# 8 target(s) with ALMA data = ['105386', 'HATLASJ121253.5-002203', 'UR7G', 'HATLASJ121427.3+005819', 'HATLAS_J140608.2+005501', 'GAMA106389', 'HATLAS_J143336.7+005042', 'PM1_9195_3702']
# --------------------------------

# %%
rf_12CO_10 = 115.27120180 #GHz
z_min = np.min(z_sdss)
z_max = np.max(z_sdss)
selected = myquery[(myquery["min_freq_GHz"] > rf_12CO_10/(1+z_max)) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 10
# Number of observations = 18
# Number of unique subbands = 40
# Total number of subbands = 61
# 12 target(s) with ALMA data = ['FJ122021.84-010827.1', '105386', 'HATLASJ121253.5-002203', 'HATLASJ121253', 'UR7G', 'GAMA64646', 'HATLASJ121427.3+005819', 'HATLAS_J140608.2+005501', 'GAMA106389', 'HATLAS_J143336.7+005042', '015028', 'PM1_9195_3702']
# --------------------------------

# %%
myquery.keys()
# Out:
# Index(['Obs', 'project_code', 'ALMA_source_name', 'RAJ2000', 'DEJ2000',
#        'ang_res_arcsec', 'min_freq_GHz', 'max_freq_GHz', 'central_freq_GHz',
#        'bandwidth_GHz', 'freq_res_kHz', 'vel_res_kms', 'LAS_arcsec',
#        'FoV_arcsec', 'cont_sens_bandwidth', 'line_sens_10kms',
#        'line_sens_native', 'MOUS_id', 'collections', 'pi_userid', 'o_ucd',
#        'obs_publisher_did', 'obs_collection', 'facility_name',
#        'instrument_name', 'obs_id', 'dataproduct_type', 'calib_level',
#        'target_name', 's_ra', 's_dec', 's_fov', 's_region', 's_xel1', 's_xel2',
#        'em_xel', 't_xel', 'pol_xel', 's_resolution', 't_min', 't_max',
#        't_exptime', 't_resolution', 'em_min', 'em_max', 'em_res_power',
#        'pol_states', 'access_url', 'access_format', 'access_estsize',
#        'proposal_id', 'data_rights', 'gal_longitude', 'gal_latitude',
#        'band_list', 'em_resolution', 'bandwidth', 'antenna_arrays',
# ...

# %%
print(myquery['min_freq_GHz'][0], myquery['max_freq_GHz'][0])
# Out:
# 137.06 138.92

# %%
np.all(myquery['RAJ2000'] == myquery['s_ra'])
# Out:
# True

# %%
myquery['project_code']
# Out:
# 0      2016.1.01288.S
# 1      2016.1.01288.S
# 2      2016.1.01288.S
# 3      2016.1.01288.S
# 4      2016.1.00386.S
#             ...
# 147    2021.1.00874.S
# 148    2019.1.00260.S
# 149    2019.1.00260.S
# 150    2019.1.00260.S
# 151    2019.1.00260.S
# Name: project_code, Length: 152, dtype: object

# %% [markdown]
# ## I need redshift for each entry in the myquery catalog (not one-to-one with input catalog), thus re-match on SDSS RA/Dec

# %%
ra_query, dec_query = np.array(myquery['RAJ2000']), np.array(myquery['DEJ2000'])

# %%
objID_query = []
z_query = []

for ra_q, dec_q in zip(ra_query, dec_query):
    
    diff = np.sqrt((ra_sdss-ra_q)**2 + (dec_sdss-dec_q)**2)
    
    if np.min(diff) > 30:
        print('Poor match!')
    
    objID_query.append(table_id[diff == np.min(diff)][0])
    z_query.append(z_sdss[diff == np.min(diff)][0])

z_query = np.array(z_query)

# %% [markdown]
# In the future I can replace the spatial_scale_max with an SDSS radius...

# %%
rf_12CO_10 = 115.27120180 #GHz

redshifted_line = rf_12CO_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 6
# Number of observations = 8
# Number of unique subbands = 7
# Total number of subbands = 10
# 7 target(s) with ALMA data = ['105386', 'HATLASJ121253.5-002203', 'UR7G', 'HATLAS_J140608.2+005501', 'GAMA106389', 'HATLAS_J143336.7+005042', 'PM1_9195_3702']
# --------------------------------

# %%
rf_12CO_21 = 230.53800000 # 12CO J=2-1
redshifted_line = rf_12CO_21/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# No observations found.
# --------------------------------
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 3
# Total number of subbands = 3
# 3 target(s) with ALMA data = ['1237648704051675158', 'GAMA64646', '1237648705664450617']
# --------------------------------

# %%
rf_12CO_32 = 345.79598990 # 12CO J=3-2
redshifted_line = rf_12CO_32/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# No observations found.
# --------------------------------
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 3
# Total number of subbands = 3
# 2 target(s) with ALMA data = ['HATLASJ121253', '015028']
# --------------------------------

# %% [markdown]
# ## Testing saving procedure

# %%
myquery.to_pickle('test.pkl')

# %%
loadedquery = pandas.read_pickle('test.pkl')

# %%
rf_12CO_32 = 345.79598990 # 12CO J=3-2
redshifted_line = rf_12CO_32/(1+z_query)

selected = loadedquery[(loadedquery["min_freq_GHz"] < redshifted_line) & 
                   (loadedquery["max_freq_GHz"] > redshifted_line) & 
                   ((loadedquery["scientific_category"] == 'Galaxy evolution') | 
                    (loadedquery["scientific_category"] == 'Active galaxies') |
                    (loadedquery["scientific_category"] == 'Cosmology') |
                    (loadedquery["scientific_category"] == 'Local Universe')) &
                   (loadedquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 3
# Total number of subbands = 3
# 2 target(s) with ALMA data = ['HATLASJ121253', '015028']
# --------------------------------

# %% [markdown]
# ### It works!

# %% [markdown]
# ## Download example galaxy

# %%
myquery = alminer.conesearch(ra=311.780975339982, dec=0.3004607000000825, point=False, search_radius=0.5)
# Out:
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 6
# 2 target(s) with ALMA data = ['587731173842027508_8623-6104', '8623-6104']
# --------------------------------

# %%
alminer.download_data(myquery, fitsonly=False, dryrun=False,
                      location='/arc/projects/salvage/ALMA_data/', print_urls=False)
# Out:
# ...
# Starting download. Please wait...
# ...
# Download location = /arc/projects/salvage/ALMA_data/
# Total number of Member OUSs to download = 2
# Selected Member OUSs: ['uid://A001/X133d/Xea3', 'uid://A001/X133d/Xf49']
# Number of files to download = 13
# Needed disk space = 24.4 GB
# --------------------------------

# %%
myquery['ALMA_source_name'][120]
# Out:
# '587731173842027508_8623-6104'

# %%
print(myquery['RAJ2000'][120], myquery['DEJ2000'][120])
# Out:
# 311.780975339982 0.3004607000000825

# %% [markdown]
# ## Try custom queries

# %%
myquery = alminer.conesearch(ra=42.46662204, dec=-0.07121246, point=False, search_radius=3, print_query=True)
# Out:
# Your query is: SELECT * FROM ivoa.ObsCore WHERE (1 = INTERSECTS(CIRCLE('ICRS',42.46662204,-0.07121246,0.05), s_region) OR 1 = CONTAINS(POINT('ICRS',42.46662204,-0.07121246), s_region)) AND data_rights LIKE '%Public%'
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['8078-6103']
# --------------------------------

# %%
query_str = "SELECT * FROM ivoa.ObsCore \
            WHERE (1 = INTERSECTS(CIRCLE('ICRS',42.46662204,-0.07121246,0.05), s_region) \
            OR 1 = CONTAINS(POINT('ICRS',42.46662204,-0.07121246), s_region)) \
            AND data_rights LIKE '%Public%'"

# %%
query_str = "SELECT * FROM ivoa.ObsCore \
            WHERE (1 = INTERSECTS(CIRCLE('ICRS',42.46662204,-0.07121246,0.05), s_region) \
            OR 1 = CONTAINS(POINT('ICRS',42.46662204,-0.07121246), s_region) \
            OR 1 = INTERSECTS(CIRCLE('ICRS',311.780975339982,0.3004607000000825, 0.05), s_region) \
            OR 1 = CONTAINS(POINT('ICRS',311.780975339982,0.3004607000000825), s_region)) \
            AND data_rights LIKE '%Public%'"

# %%
myquery = alminer.run_query(query_str)
myquery = alminer.filter_results(myquery)
# Out:
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 7
# Total number of subbands = 8
# 3 target(s) with ALMA data = ['8078-6103', '587731173842027508_8623-6104', '8623-6104']
# --------------------------------

# %%
mycat = pandas.DataFrame(mycat)

myquery = alminer.catalog(mycat, search_radius = 3, print_query=True)
# Out:
# ...
# alminer.catalog results
# ...
# Target = 587731511545626673
# Your query is: SELECT * FROM ivoa.ObsCore WHERE (1 = INTERSECTS(CIRCLE('ICRS',49.82143689,-0.96964645,0.05), s_region) OR 1 = CONTAINS(POINT('ICRS',49.82143689,-0.96964645), s_region)) AND data_rights LIKE '%Public%'
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['587731511545626673_8081-3704']
# --------------------------------
# Target = 588015510364880957
# Your query is: SELECT * FROM ivoa.ObsCore WHERE (1 = INTERSECTS(CIRCLE('ICRS',49.78215908,0.95595472,0.05), s_region) OR 1 = CONTAINS(POINT('ICRS',49.78215908,0.95595472), s_region)) AND data_rights LIKE '%Public%'
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['588015510364880957_8082-6103']
# ...

# %% [markdown]
# ## Time custom query vs individual queries

# %%
import pymysql, time
import numpy as np

#Query MySQL for mock survey statmorph results
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 9 AND u.z_spec < 0.2 AND u.decl < 47'
x = 'SELECT DISTINCT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u, dr15_ALMA_spaxels a WHERE u.objID = a.objID AND u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 AND u.ra > 20 and u.ra < 35'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
len(ra_sdss)
# Out:
# 51

# %%
mycat =  {"Name": table_id,
          "RAJ2000" : ra_sdss,
          "DEJ2000" : dec_sdss,
           "z": z_sdss}

mycat = pandas.DataFrame(mycat)

start = time.time()
myquery = alminer.catalog(mycat, search_radius = 3)
end = time.time()
# Out:
# ...
# alminer.catalog results
# ...
# Target = 587731511545626673
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['587731511545626673_8081-3704']
# --------------------------------
# Target = 588015510364880957
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['588015510364880957_8082-6103']
# --------------------------------
# Target = 588015509828075649
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['WP_8083_12703', '8083-12703']
# --------------------------------
# Target = 588015507657719904
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# ...

# %%
alminer.summary(myquery)
# Out:
# --------------------------------
# Number of projects = 10
# Number of observations = 62
# Number of unique subbands = 192
# Total number of subbands = 201
# ...

# %%
print(f'This query took {(end-start)/60} min.')
# Out:
# This query took 1.1573679010073343 min.

# %%
query_str = "SELECT * FROM ivoa.ObsCore WHERE data_rights LIKE '%Public%' AND ("

search_radius = 3 # arcmin
search_radius_deg = search_radius/60

initialized = False

for r, d in zip(ra_sdss, dec_sdss):
    
    if not initialized:
    
        query_str += f"1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
        initialized = True
        
    else: 
        
        query_str += f"OR 1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
    
    query_str += f"OR 1 = CONTAINS(POINT('ICRS',{r},{d}), s_region) "

query_str += ')'

# %%
start = time.time()
myquery = alminer.run_query(query_str)
myquery = alminer.filter_results(myquery)
end = time.time()
print(f'This query took {(end-start)/60} min.')
# Out:
# --------------------------------
# Number of projects = 10
# Number of observations = 62
# Number of unique subbands = 192
# Total number of subbands = 201
# ...

# %% [markdown]
# ### Then match on redshift to check for line coverage in spectral windows...

# %%
ra_query, dec_query = np.array(myquery['RAJ2000']), np.array(myquery['DEJ2000'])

# %%
objID_query = []
z_query = []

for ra_q, dec_q in zip(ra_query, dec_query):
    
    diff = np.sqrt((ra_sdss-ra_q)**2 + (dec_sdss-dec_q)**2)
    
    if np.min(diff) > 30:
        print('Poor match!')
    
    objID_query.append(table_id[diff == np.min(diff)][0])
    z_query.append(z_sdss[diff == np.min(diff)][0])

z_query = np.array(z_query)

# %% [markdown]
# In the future I can replace the spatial_scale_max with an SDSS radius...

# %%
rf_12CO_10 = 115.27120180 #GHz

redshifted_line = rf_12CO_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 6
# Number of observations = 53
# Number of unique subbands = 52
# Total number of subbands = 53
# ...

# %%
rf_12CO_21 = 230.53800000 # 12CO J=2-1
redshifted_line = rf_12CO_21/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 1
# Total number of subbands = 1
# 1 target(s) with ALMA data = ['GMP3896']
# --------------------------------

# %% [markdown]
# ## How many lines can I write to the query before it breaks?

# %%
#Query MySQL for mock survey statmorph results
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 LIMIT 1000'
#x = 'SELECT DISTINCT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u, dr15_ALMA_spaxels a WHERE u.objID = a.objID AND u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 AND u.ra > 20 and u.ra < 35'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
query_str = "SELECT * FROM ivoa.ObsCore WHERE data_rights LIKE '%Public%' AND ("

search_radius = 3 # arcmin
search_radius_deg = search_radius/60

initialized = False

for r, d in zip(ra_sdss, dec_sdss):
    
    if not initialized:
    
        query_str += f"1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
        initialized = True
        
    else: 
        
        query_str += f"OR 1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
    
    query_str += f"OR 1 = CONTAINS(POINT('ICRS',{r},{d}), s_region) "

query_str += ')'

# %%
start = time.time()
myquery = alminer.run_query(query_str)
myquery = alminer.filter_results(myquery)
end = time.time()
print(f'This query took {(end-start)/60} min.')
# Out:
# --------------------------------
# Number of projects = 8
# Number of observations = 26
# Number of unique subbands = 44
# Total number of subbands = 104
# 25 target(s) with ALMA data = ['70mJy_4', '40mJy_12', '70mJy_3', '40mJy_17', 'Ganymede', 'HATLAS_RED_2201', 'HATLAS_RED_1334', 'HATLAS_RED_1251', 'HATLAS_RED_1252', 'HATLAS_RED_1258', 'HATLAS_RED_1178', '132139.86-004151.9', 'Callisto', 'FJ122021.84-010827.1', 'HATLAS1061', 'HATLAS1066', 'HATLAS1071', 'HATLAS1096', 'HATLAS1155', 'HATLAS1651', 'HATLAS1083', 'HATLAS1121', 'HATLAS371', 'HATLAS376', 'HATLAS1685']
# --------------------------------
# This query took 7.762967991828918 min.

# %% [markdown]
# ### Try uploading data to TAP before query

# %%
#Query MySQL for mock survey statmorph results
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 LIMIT 1000'
#x = 'SELECT DISTINCT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u, dr15_ALMA_spaxels a WHERE u.objID = a.objID AND u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
#x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47 AND u.ra > 20 and u.ra < 35'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
import os

# %%
'xyz'.replace('y','z')
# Out:
# 'xzz'

# %%
template_file = 'template_tap.txt'
path_to_template = '/arc/projects/salvage/ALMAxmatch/notebooks/'

table_file = 'sdss_positions_tap.txt'
path_to_file = '/arc/projects/salvage/ALMAxmatch/notebooks/'

os.system(f'cp {path_to_template + template_file} {path_to_file + table_file}')

out = open(path_to_file + table_file, 'r')
out_data = out.read()
out.close()

search_radius = 3 # arcmin
search_radius_deg = search_radius/60

coords_str = ''

for r, d in zip(ra_sdss[0:2], dec_sdss[0:2]):

    
    coords_str += "          <TR>\n" 
    coords_str += f"            <TD>{r}</TD>\n"
    coords_str += f"            <TD>{d}</TD>\n"
    coords_str += "          </TR>\n"
    coords_str += "\n"

out_data = out_data.replace('          __COORDS__', coords_str)

out = open(path_to_file + table_file, 'w')
out.write(out_data)
out.close()

# %%
output_file = 'sdss_x_alma_positions.txt'
path_to_output = '/arc/projects/salvage/ALMAxmatch/notebooks/'

start = time.time()
os.system(f'cadc-tap query -s https://almascience.org/tap --tmptable mytable:{path_to_file + table_file} \
        "SELECT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t \
        ON (1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, 0.05), s_region) OR 1 = CONTAINS(POINT(\'ICRS\',t.s_ra, t.s_dec), oc.s_region)) AND oc.data_rights LIKE \'%Public%\'"\
        > {path_to_output + output_file}')
end = time.time()
# Out:
# ERROR:: failed to read table mytable from https://almascience.nrao.edu/tap/files/sdss_positions_tap.txt-x81v3a2nrjvxtu5x

# %%
!

# %%
print(f'This query took {(end-start)/60} min.')
# Out:
# This query took 0.019384698073069254 min.

# %%
f'cadc-tap query -s https://almascience.org/tap --tmptable mytable:{path_to_file + table_file} \
        "SELECT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t \
        ON (1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, 0.05), s_region) OR 1 = CONTAINS(POINT(\'ICRS\',t.s_ra, t.s_dec), oc.s_region)) AND oc.data_rights LIKE \'%Public%\'"\
        > {path_to_output + output_file}'
# Out:
# 'cadc-tap query -s https://almascience.org/tap --tmptable mytable:/arc/projects/salvage/ALMAxmatch/notebooks/sdss_positions_tap.txt         "SELECT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t         ON (1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, 0.05), s_region) OR 1 = CONTAINS(POINT(\'ICRS\',t.s_ra, t.s_dec), oc.s_region)) AND oc.data_rights LIKE \'%Public%\'"        > /arc/projects/salvage/ALMAxmatch/notebooks/sdss_x_alma_positions.txt'

# %%
! cadc-tap query -s https://almascience.org/tap --tmptable mytable:/arc/projects/salvage/ALMAxmatch/notebooks/sdss_positions_tap.txt "SELECT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t ON (1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, 0.05), s_region) OR 1 = CONTAINS(POINT(\'ICRS\',t.s_ra, t.s_dec), oc.s_region)) AND oc.data_rights LIKE \'%Public%\'" > /arc/projects/salvage/ALMAxmatch/notebooks/sdss_x_alma_positions.txt
# Out:
# ERROR:: failed to read table mytable from https://almascience.nrao.edu/tap/files/sdss_positions_tap.txt-t9prrki3g1tiskrh
