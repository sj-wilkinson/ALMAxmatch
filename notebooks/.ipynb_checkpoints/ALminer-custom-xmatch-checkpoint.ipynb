# %%
import alminer, pandas, pymysql, time, glob, os
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import alminer, pandas, pymysql, time, glob, os
#       2 import numpy as np
#
# File ~/.local/lib/python3.10/site-packages/alminer/__init__.py:7
#       1 """
#       2 ALminer: ALMA archive mining and visualization toolkit
#       3 ======================================================
#       4 A package for mining the Atacama Large Millimeter/submillimeter
#       5 Array (ALMA) data archive and visualizing the queried observations.
#       6 """
# ----> 7 from .alminer import catalog, CO_lines, conesearch, download_data, explore, filter_results, get_description, \
#       8     get_units, get_info, keysearch, line_coverage, plot_line_overview, plot_overview, plot_observations, plot_bands, \
#       9     plot_sky, run_query, summary, target, save_source_reports, save_table
#      10 __all__ = ["catalog", "CO_lines", "conesearch", "download_data", "explore", "filter_results",
#      11            "get_description", "get_units", "get_info", "keysearch", "line_coverage", "plot_line_overview",
#      12            "plot_overview", "plot_observations", "plot_bands", "plot_sky", "run_query", "summary",
#      13            "target", "save_source_reports", "save_table"]
#      14 try:
#
# File ~/.local/lib/python3.10/site-packages/alminer/alminer.py:11
#       9 import os
#      10 import re
# ---> 11 import pandas as pd
#      12 import numpy as np
#      13 np.set_printoptions(threshold=np.inf)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/__init__.py:16
#      13         _missing_dependencies.append(f"{_dependency}: {_e}")
#      15 if _missing_dependencies:
# ---> 16     raise ImportError(
#      17         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      18     )
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.10 from "/opt/conda/bin/python"
#   * The NumPy version is: "1.25.2"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: cannot import name '_ArrayFunctionDispatcher' from 'numpy.core._multiarray_umath' (/opt/conda/lib/python3.10/site-packages/numpy/core/_multiarray_umath.cpython-310-x86_64-linux-gnu.so)

# %%
def build_tmp_table(ra, dec, search_radius_arcmin):
    
    # construct a temporary table from template

    template_file = 'template_tap.txt'
    path_to_template = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    table_file = 'sdss_positions_tap.txt'
    path_to_file = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    os.system(f'cp {path_to_template + template_file} {path_to_file + table_file}')

    # get template table (formatting with no coordinates)
    out = open(path_to_file + table_file, 'r')
    out_data = out.read()
    out.close()

    search_radius_deg = search_radius_arcmin/60

    # initialize string
    coords_str = ''

    # format the ra and dec's for html table
    for r, d in zip(ra, dec):

        coords_str += "          <TR>\n" 
        coords_str += f"            <TD>{r}</TD>\n"
        coords_str += f"            <TD>{d}</TD>\n"
        coords_str += "          </TR>\n"
        coords_str += "\n"

    # replace __COORDS__ in template with formatted coords
    out_data = out_data.replace('          __COORDS__', coords_str)

    # write to new table
    out = open(path_to_file + table_file, 'w')
    out.write(out_data)
    out.close()
    
    return table_file, path_to_file

def generate_query(ra, dec, search_radius_arcmin = 0.5):
    
    # generate a custom ALminer query from a list of known hits

    query_str = "SELECT * FROM ivoa.ObsCore WHERE data_rights LIKE '%Public%' AND ("

    search_radius_deg = search_radius_arcmin/60

    initialized = False

    for r, d in zip(ra, dec):

        if not initialized:

            query_str += f"1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 
            initialized = True

        else: 

            query_str += f"OR 1 = INTERSECTS(CIRCLE('ICRS',{r}, {d}, {search_radius_deg}), s_region) " 

        query_str += f"OR 1 = CONTAINS(POINT('ICRS',{r},{d}), s_region) "

    query_str += ')'
    
    return query_str

# %%
#Query MySQL for SDSS positions
db = pymysql.connect(host = 'lauca.phys.uvic.ca', db = 'sdss', user = 'swilkinson', passwd = '123Sdss!@#')
x = 'SELECT u.objID, u.ra, u.decl, u.total_mass_med, u.z_spec FROM  dr7_uberuber u WHERE u.total_mass_med > 1 AND u.z_spec < 0.5 AND u.decl < 47'
c = db.cursor()
c.execute(x)
db_data = c.fetchall()
c.close()
db.close()
	
# transpose queried table
data = np.array(db_data, dtype = float).T
table_id = np.array(db_data, dtype = str).T[0]

# %%
ra_sdss = data[1]
dec_sdss = data[2]
z_sdss = data[4]

# %%
len(ra_sdss)

# %%
10/60

# %%
# split up targets into separate jobs (nJobs)
nJobs = 300

# number of targets in each job
N = int(np.ceil(len(ra_sdss)/nJobs))
print(N)

# number of completed jobs to start from
completed = 0

# run query jobs in serial    
for i in np.arange(completed, nJobs, 1):
    
    ### splitting up targets
    if i == nJobs-1:
    
        ra_table = ra_sdss[i*N:]
        dec_table = dec_sdss[i*N:]
        
    else:
    
        ra_table = ra_sdss[i*N:(i+1)*N]
        dec_table = dec_sdss[i*N:(i+1)*N]
        
    ### create temporary table with target subset    
    table_file, path_to_file = build_tmp_table(ra_table, dec_table, search_radius_arcmin = 0.5)
    
    search_radius_arcmin = 0.5
    search_radius_deg = search_radius_arcmin/60
    
    output_file = 'sdss_x_alma_positions.txt'
    path_to_output = '/arc/projects/salvage/ALMAxmatch/notebooks/'

    # wipe old output file
    tmp = open(path_to_output+output_file, 'w')
    tmp.close()
    
    ### query with cadc-tap
    start = time.time()
    os.system(f'cadc-tap query -s https://almascience.nao.ac.jp/tap --tmptable mytable:{path_to_file + table_file} \
            "SELECT DISTINCT oc.s_ra, oc.s_dec FROM ivoa.obscore oc JOIN tap_upload.mytable t \
            ON 1 = INTERSECTS(CIRCLE(\'ICRS\', t.s_ra, t.s_dec, {search_radius_deg}), oc.s_region) AND oc.data_rights LIKE \'%Public%\'"\
            > {path_to_output + output_file}')
    end = time.time()
    print(f'Querying {N} galaxies took {(end-start)/60} min.')
    
    
    ### convert results to an ALminer query object
    
    
    # remove last two lines of the text file

    out = open(path_to_output + output_file, 'r')
    lines = out.readlines()
    out.close()

    lines = lines[:-2]

    out = open(path_to_output + output_file, 'w')
    out.write(''.join(lines))
    out.close()
    
    if len(lines) < 3:
        print('No matches!')
        continue
    
    # collect ra and dec of all sub-band ra-dec
    ra_match, dec_match = np.loadtxt(path_to_output + output_file, unpack = True, skiprows = 2)
    
    #print(type(ra_match), type(dec_match))
    
    if type(ra_match) == np.float64:
        ra_match_unique = np.array([ra_match])
        dec_match_unique = np.array([dec_match])
        
    else:

        # generate strings of ra_dec pairs to identify unique targets
        rd_str = np.array([f'{r}_{d}' for r, d in zip(ra_match, dec_match)])

        # identify unique targets from xmatch output
        rd_str_unique, index_unique = np.unique(rd_str, return_index = True)
        ra_match_unique = ra_match[index_unique]
        dec_match_unique = dec_match[index_unique]
    
    # generate a custom ALminer query from xmatch hits
    query_str = generate_query(ra_match_unique, dec_match_unique, search_radius_arcmin = 0.5)
    
    start = time.time()
    myquery = alminer.run_query(query_str)
    myquery = alminer.filter_results(myquery)
    end = time.time()
    print(f'This query took {(end-start)/60} min.')

    # if there are observations found, print out summary and save for later
    if myquery is None:
        print('No observations found in query.')
    else:
        
        # print out summary
        #alminer.summary(myquery)
        
        # pickle data for later
        myquery.to_pickle(f'/arc/projects/salvage/ALMAxmatch/ALminer_output/SDSS-ALMA-search-Nov14-Job{i}.pkl')
# Out:
# 1896
# Querying 1896 galaxies took 0.5116713921229045 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 6
# Number of unique subbands = 24
# Total number of subbands = 24
# 3 target(s) with ALMA data = ['J1521+0420', 'HATLAS701', 'AGC252580']
# --------------------------------
# This query took 0.026266451676686606 min.
# Querying 1896 galaxies took 0.3773775577545166 min.
# No matches!
# Querying 1896 galaxies took 0.2824346701304118 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 16
# Total number of subbands = 30
# 3 target(s) with ALMA data = ['0570_537_52266', 'S05', 'VV75']
# --------------------------------
# This query took 0.02866732676823934 min.
# Querying 1896 galaxies took 0.34226040840148925 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['653728']
# --------------------------------
# This query took 0.021885228157043458 min.
# Querying 1896 galaxies took 0.39986876646677655 min.
# No matches!
# ERROR:: failed to read table mytable from https://almascience.nao.ac.jp/tap/files/sdss_positions_tap.txt-coafnc43daobrmbx
# Querying 1896 galaxies took 0.024777313073476154 min.
# No matches!
# Querying 1896 galaxies took 0.3119726538658142 min.
# No matches!
# Querying 1896 galaxies took 0.5210712313652038 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 12
# Total number of subbands = 20
# 5 target(s) with ALMA data = ['1237655495979106610', 'HATLAS1783', 'HATLAS1674', 'HATLAS1730', '263667']
# --------------------------------
# This query took 0.03858416477839152 min.
# Querying 1896 galaxies took 0.3322752356529236 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['VV847', '170103']
# --------------------------------
# This query took 0.024925053119659424 min.
# ERROR:: failed to read table mytable from https://almascience.nao.ac.jp/tap/files/sdss_positions_tap.txt-eldki17atjjlmpus
# Querying 1896 galaxies took 0.03025351365407308 min.
# No matches!
# Querying 1896 galaxies took 0.2746005455652873 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['19', 'PM2_7975_6104']
# --------------------------------
# This query took 0.026929505666097007 min.
# Querying 1896 galaxies took 0.30218366781870526 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 18
# Total number of subbands = 18
# 2 target(s) with ALMA data = ['Neptune', 'UGC11958']
# --------------------------------
# This query took 0.07954267263412476 min.
# Querying 1896 galaxies took 0.29573052724202475 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 10
# Number of unique subbands = 37
# Total number of subbands = 41
# 3 target(s) with ALMA data = ['Neptune', 'C22-2', '16911']
# --------------------------------
# This query took 0.04085328578948975 min.
# Querying 1896 galaxies took 0.23706884384155275 min.
# No matches!
# Querying 1896 galaxies took 0.38305847644805907 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 25
# Total number of subbands = 28
# 5 target(s) with ALMA data = ['299299', '456147', 'GAMA496966', 'RXCJ1504.1-0248', 'APX_SB2_5']
# --------------------------------
# This query took 0.03802318175633748 min.
# Querying 1896 galaxies took 0.26464027166366577 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['HATLAS_J143701.0-010421', 'HATLAS_RED_2358', '29955']
# --------------------------------
# This query took 0.029239555199940998 min.
# Querying 1896 galaxies took 0.25430988073349 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['NGC7194']
# --------------------------------
# This query took 0.024168455600738527 min.
# Querying 1896 galaxies took 0.28611655632654825 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 7
# Number of unique subbands = 26
# Total number of subbands = 26
# 3 target(s) with ALMA data = ['Neptune', 'dm2227-09', 'Mars']
# --------------------------------
# This query took 0.038013188044230144 min.
# Querying 1896 galaxies took 0.29321951468785606 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 11
# Number of unique subbands = 39
# Total number of subbands = 40
# 10 target(s) with ALMA data = ['RXJ2129.7+0005', '7964-1902', 'PM1_8615_1901', 'PM1_8623_1902', '587731173842027508_8623-6104', 'H04', '8615-9101', '8623-6104', 'SDSS_J211333.80-000950.4', 'SDSS_J211307.21+005108.5']
# --------------------------------
# This query took 0.042745566368103026 min.
# Querying 1896 galaxies took 0.3196759819984436 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 21
# Number of unique subbands = 74
# Total number of subbands = 78
# 13 target(s) with ALMA data = ['SDSS_J2118+0017', '8655-3701', 'Uranus', 'HELMS_RED_385', 'VV492', 'SDSSJ2118+0017', '8623-12702', 'cQSO_J235517.22-001157.1', '8616-1902', '8655-1902', 'ACT-S_J234648-000519', 'WP_8616_9101', 'cQSO_J220943.43-003338.7']
# --------------------------------
# This query took 0.06009530226389567 min.
# Querying 1896 galaxies took 0.3251513878504435 min.
# --------------------------------
# Number of projects = 28
# Number of observations = 71
# Number of unique subbands = 151
# Total number of subbands = 276
# 43 target(s) with ALMA data = ['AGN8', 'ADF22', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', 'NBJ-CFHT-C343', 'SSA22-AZ001', 'SSA22-AZ010', 'AzTEC14', 'AzTEC1', 'mADF22', 'Core_region', 'ALMAJ221737.43+001710.7', 'eADF22tile1', 'SSA22-AzTEC14', 'SSA22-AzTEC1', 'WHDF-LAB-03', 'ALMAJ221731.95+001820.3', 'UGC01123', 'SSA22-AzTEC105', 'ADF22.A1', 'ADF22.A5', '8086-9101', 'ADF22.A4', 'ADF22.A7', 'ADF22.10', 'ADF22.A8', 'ADF22.A12', 'ADF22.15', 'ADF22.A17', 'ADF22.A16', 'PM2_8153_12702', 'CP_7968_12705', 'dm0052+00_I116', 'dm0052+00_I115', 'SSA.0007', 'DSFG4', 'DSFG1', 'RXCJ2341.1+0018', 'SSA.0001', 'SSA.0029', 'WP_8085_12701']
# --------------------------------
# This query took 0.0988267183303833 min.
# Querying 1896 galaxies took 0.4484678268432617 min.
# --------------------------------
# Number of projects = 17
# Number of observations = 29
# Number of unique subbands = 109
# Total number of subbands = 116
# 11 target(s) with ALMA data = ['587731513694355564_8155-6102', '9io9', 'pg_0157+001', 'SHELA_z4_554210', 'HERS1', 'Mrk1014', 'hers1', 'PJ020941.3', '8081-9102', 'IRAS_01572+0009', 'CP_8078_6104']
# --------------------------------
# This query took 0.07352438767751059 min.
# Querying 1896 galaxies took 0.22601070404052734 min.
# No matches!
# Querying 1896 galaxies took 0.24152570168177287 min.
# No matches!
# Querying 1896 galaxies took 0.24888362884521484 min.
# No matches!
# Querying 1896 galaxies took 0.3391924897829692 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 14
# Total number of subbands = 14
# 4 target(s) with ALMA data = ['SDSS_212639.87+001830.0', '1237657190888898714', '587731186187632690_8616-9102', '8616-6104']
# --------------------------------
# This query took 0.03622881174087524 min.
# Querying 1896 galaxies took 0.347581148147583 min.
# --------------------------------
# Number of projects = 14
# Number of observations = 14
# Number of unique subbands = 53
# Total number of subbands = 54
# 13 target(s) with ALMA data = ['RFGC296', '1237657070091960362', 'IMS_J2204+0112', 'SHELA_z4_678917', 'QSO_J0138-0005', 'Ceres', 'Q01322-0051', '8080-3704', 'QSO 0138-0005', '8081-9101', 'WP_8085_3704', '587731512617664623_8154-9102', 'IMSJ2204+0112']
# --------------------------------
# This query took 0.054631702105204266 min.
# Querying 1896 galaxies took 0.27480465173721313 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 11
# Number of unique subbands = 29
# Total number of subbands = 37
# 8 target(s) with ALMA data = ['8081-12703', 'CP_8085_6101', 'S02', '587731512619696292_8084-3702', '0413_238_51929', '8081-6102', 'dm0346+00_I110', 'dm0346+00_I109']
# --------------------------------
# This query took 0.05569222370783488 min.
# Querying 1896 galaxies took 0.26693911155064903 min.
# No matches!
# Querying 1896 galaxies took 0.280266280968984 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['IC_485', '8941-3701']
# --------------------------------
# This query took 0.026684109369913736 min.
# Querying 1896 galaxies took 0.27247215112050377 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['8149-12704']
# --------------------------------
# This query took 0.0209043025970459 min.
# Querying 1896 galaxies took 0.22755783398946125 min.
# No matches!
# Querying 1896 galaxies took 0.24433385133743285 min.
# No matches!
# Querying 1896 galaxies took 0.24305067857106527 min.
# No matches!
# Querying 1896 galaxies took 0.24725677967071533 min.
# No matches!
# Querying 1896 galaxies took 0.25178956190745033 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['J1057']
# --------------------------------
# This query took 0.022559944788614908 min.
# Querying 1896 galaxies took 0.2728713512420654 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 7
# Number of unique subbands = 30
# Total number of subbands = 34
# 4 target(s) with ALMA data = ['Ganymede', 'Callisto', 'J092042.47+054412.3', '084401.95+050357.9']
# --------------------------------
# This query took 0.044109892845153806 min.
# Querying 1896 galaxies took 0.2597869118054708 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 18
# Number of unique subbands = 69
# Total number of subbands = 69
# 7 target(s) with ALMA data = ['G244.8+54.9', 'J1053', '11107', 'Ganymede', 'PLCK_G244.8+54.9', 'Callisto', 'PJ105353']
# --------------------------------
# This query took 0.05635491609573364 min.
# Querying 1896 galaxies took 0.2518656373023987 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 8
# Number of unique subbands = 26
# Total number of subbands = 29
# 6 target(s) with ALMA data = ['Ganymede', 'IRAS_09039+0503', 'J1010+0612', 'SDSS_J101043.36+061201.4', '445641', '318424']
# --------------------------------
# This query took 0.041005245844523114 min.
# Querying 1896 galaxies took 0.25636176268259686 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 7
# Number of unique subbands = 17
# Total number of subbands = 21
# 4 target(s) with ALMA data = ['J1108+0659', 'G08-5', 'dm0916+06_I040', 'dm0916+06_I039']
# --------------------------------
# This query took 0.035679864883422854 min.
# Querying 1896 galaxies took 0.23199090162913005 min.
# No matches!
# Querying 1896 galaxies took 0.23625609079996746 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['NGC_6264']
# --------------------------------
# This query took 0.02473495403925578 min.
# Querying 1896 galaxies took 0.22311569849650065 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['rQSO_J221646.47-003917.8']
# --------------------------------
# This query took 0.02402489185333252 min.
# Querying 1896 galaxies took 0.29969335397084557 min.
# No matches!
# Querying 1896 galaxies took 0.26169904867808025 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['IRAS_F10173+0828']
# --------------------------------
# This query took 0.03345692157745361 min.
# Querying 1896 galaxies took 0.24138024648030598 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['530542']
# --------------------------------
# This query took 0.020810508728027345 min.
# Querying 1896 galaxies took 0.23347822427749634 min.
# No matches!
# Querying 1896 galaxies took 0.24526625871658325 min.
# No matches!
# Querying 1896 galaxies took 0.2375222126642863 min.
# No matches!
# ERROR:: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>502 Proxy Error</title>
# </head><body>
# <h1>Proxy Error</h1>
# <p>The proxy server received an invalid
# response from an upstream server.<br />
# The proxy server could not handle the request <em><a href="/tap/sync">POST&nbsp;/tap/sync</a></em>.<p>
# Reason: <strong>Error reading from remote server</strong></p></p>
# </body></html>
# Querying 1896 galaxies took 0.022428512573242188 min.
# No matches!
# Querying 1896 galaxies took 0.2288055380185445 min.
# No matches!
# Querying 1896 galaxies took 0.2552093267440796 min.
# No matches!
# Querying 1896 galaxies took 0.26491512060165406 min.
# --------------------------------
# Number of projects = 37
# Number of observations = 54
# Number of unique subbands = 188
# Total number of subbands = 213
# 4 target(s) with ALMA data = ['J2226+0052', '0379_579_51789', 'S15', 'ERQ_J222646.53+005211.2']
# --------------------------------
# This query took 0.04482113520304362 min.
# Querying 1896 galaxies took 0.276127290725708 min.
# No matches!
# Querying 1896 galaxies took 0.32936957677205403 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['658645', 'IC_2810', 'RXJ0820.9+0752']
# --------------------------------
# This query took 0.030987258752187094 min.
# Querying 1896 galaxies took 0.34172939459482826 min.
# --------------------------------
# Number of projects = 15
# Number of observations = 37
# Number of unique subbands = 99
# Total number of subbands = 145
# 8 target(s) with ALMA data = ['M100', 'Pallas', 'NGC_4321', 'SN2020oi', '373633', 'ngc4321', 'J0909+1052', 'NGC4321']
# --------------------------------
# This query took 0.060456347465515134 min.
# Querying 1896 galaxies took 0.34767788648605347 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 5
# Total number of subbands = 12
# 1 target(s) with ALMA data = ['NGC2859']
# --------------------------------
# This query took 0.026639175415039063 min.
# Querying 1896 galaxies took 0.28885372877120974 min.
# No matches!
# Querying 1896 galaxies took 0.2976988196372986 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['070521', 'IC1079']
# --------------------------------
# This query took 0.026699364185333252 min.
# Querying 1896 galaxies took 0.28507378498713176 min.
# No matches!
# Querying 1896 galaxies took 0.32705241441726685 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['113989']
# --------------------------------
# This query took 0.021592899163564046 min.
# Querying 1896 galaxies took 0.336904780069987 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['5511']
# --------------------------------
# This query took 0.023627666632334392 min.
# Querying 1896 galaxies took 0.30515729983647666 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 7
# Total number of subbands = 19
# 2 target(s) with ALMA data = ['NGC3384', 'J1055+1102']
# --------------------------------
# This query took 0.03439778486887614 min.
# Querying 1896 galaxies took 0.352690327167511 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 17
# Total number of subbands = 20
# 2 target(s) with ALMA data = ['4C+29.30', 'SDSS_081958.64+262311.3']
# --------------------------------
# This query took 0.03535473346710205 min.
# Querying 1896 galaxies took 0.2540282646814982 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['UGC05396']
# --------------------------------
# This query took 0.022528199354807536 min.
# Querying 1896 galaxies took 0.2466432015101115 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 11
# Number of unique subbands = 40
# Total number of subbands = 44
# 5 target(s) with ALMA data = ['Pallas', 'NGC4419', 'NGC4540', 'NGC_4419', '640777']
# --------------------------------
# This query took 0.04039186239242554 min.
# Querying 1896 galaxies took 0.23494528929392497 min.
# No matches!
# Querying 1896 galaxies took 0.23795066674550375 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['RXCJ1350.3+0940']
# --------------------------------
# This query took 0.024658230940500896 min.
# Querying 1896 galaxies took 0.23247884114583334 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['7987']
# --------------------------------
# This query took 0.02239742676417033 min.
# Querying 1896 galaxies took 0.22707277536392212 min.
# No matches!
# Querying 1896 galaxies took 0.24248230457305908 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['9088-9102']
# --------------------------------
# This query took 0.024332181612650553 min.
# Querying 1896 galaxies took 0.22639830907185873 min.
# No matches!
# Querying 1896 galaxies took 0.23921407063802083 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 17
# Total number of subbands = 21
# 4 target(s) with ALMA data = ['NGC_6106', 'J1430+1339', 'SDSS_J143029.88+133912.0', 'Teacup_AGN']
# --------------------------------
# This query took 0.03756914138793945 min.
# Querying 1896 galaxies took 0.23410771290461221 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['5249']
# --------------------------------
# This query took 0.02297464609146118 min.
# Querying 1896 galaxies took 0.4104890425999959 min.
# No matches!
# Querying 1896 galaxies took 0.3696276466051737 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 20
# Number of unique subbands = 62
# Total number of subbands = 82
# 3 target(s) with ALMA data = ['AT2018cow', '10993', 'AT2018cowATLAS18qqn']
# --------------------------------
# This query took 0.07254151105880738 min.
# Querying 1896 galaxies took 0.23984509309132893 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['313075']
# --------------------------------
# This query took 0.02200008233388265 min.
# Querying 1896 galaxies took 0.24266823132832846 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['IRAS_F13443+0802', '411612']
# --------------------------------
# This query took 0.025637253125508627 min.
# Querying 1896 galaxies took 0.2540287971496582 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 5
# 2 target(s) with ALMA data = ['AGC_8585', 'Q14550+0715']
# --------------------------------
# This query took 0.026373608907063802 min.
# Querying 1896 galaxies took 0.2233272353808085 min.
# No matches!
# Querying 1896 galaxies took 0.22407588164011638 min.
# No matches!
# Querying 1896 galaxies took 0.2289663275082906 min.
# No matches!
# Querying 1896 galaxies took 0.23851917187372842 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 6
# Total number of subbands = 6
# 2 target(s) with ALMA data = ['7598', '321551']
# --------------------------------
# This query took 0.03661629358927409 min.
# Querying 1896 galaxies took 0.22981446186701457 min.
# No matches!
# Querying 1896 galaxies took 0.252098015944163 min.
# No matches!
# Querying 1896 galaxies took 0.29403152465820315 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 7
# Total number of subbands = 7
# 2 target(s) with ALMA data = ['IRAS_10190+1322', 'IRAS_F10190+1322']
# --------------------------------
# This query took 0.026764102776845298 min.
# Querying 1896 galaxies took 0.24181396166483562 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 4
# Number of unique subbands = 13
# Total number of subbands = 16
# 2 target(s) with ALMA data = ['NGC3596', '26634']
# --------------------------------
# This query took 0.03517915805180868 min.
# Querying 1896 galaxies took 0.22861727873484294 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 16
# Number of unique subbands = 32
# Total number of subbands = 62
# 9 target(s) with ALMA data = ['NGC_4254', 'NGC4254', '1994018546606172160', '656018', '577834', '437037', 'ngc4254_enuc001', 'ngc4254', 'DDO_155']
# --------------------------------
# This query took 0.05150710741678874 min.
# Querying 1896 galaxies took 0.22098567883173625 min.
# No matches!
# Querying 1896 galaxies took 0.26469970544179283 min.
# No matches!
# Querying 1896 galaxies took 0.2581476370493571 min.
# No matches!
# Querying 1896 galaxies took 0.2603459159533183 min.
# No matches!
# Querying 1896 galaxies took 0.2506962259610494 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['2408']
# --------------------------------
# This query took 0.02227995793024699 min.
# Querying 1896 galaxies took 0.23291591803232828 min.
# No matches!
# Querying 1896 galaxies took 0.2486814260482788 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['127995']
# --------------------------------
# This query took 0.021687122186024983 min.
# Querying 1896 galaxies took 0.23471282323201498 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['224444']
# --------------------------------
# This query took 0.0226024587949117 min.
# Querying 1896 galaxies took 0.2206065853436788 min.
# No matches!
# Querying 1896 galaxies took 0.2539570848147074 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['CIG234']
# --------------------------------
# This query took 0.02913633584976196 min.
# Querying 1896 galaxies took 0.2784030477205912 min.
# No matches!
# Querying 1896 galaxies took 0.27287983894348145 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 8
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['NGC2595', 'IC2341', 'PGC57003']
# --------------------------------
# This query took 0.028500886758168538 min.
# Querying 1896 galaxies took 0.23424888451894124 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HATLAS_RED_1724']
# --------------------------------
# This query took 0.024720231691996258 min.
# Querying 1896 galaxies took 0.2842624505360921 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 2
# Total number of subbands = 2
# 2 target(s) with ALMA data = ['J132838.16+333618.3', 'J133306.57+330903.7']
# --------------------------------
# This query took 0.0292691707611084 min.
# Querying 1896 galaxies took 0.24282068411509197 min.
# No matches!
# Querying 1896 galaxies took 0.23104662497838338 min.
# No matches!
# Querying 1896 galaxies took 0.25200493733088175 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['HATLAS_RED_1547', 'HATLAS_RED_1823']
# --------------------------------
# This query took 0.026035376389821372 min.
# Querying 1896 galaxies took 0.23514564037323 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 10
# 3 target(s) with ALMA data = ['CGCG_165-035', 'HATLAS_RED_1699', '4579']
# --------------------------------
# This query took 0.047641475995381675 min.
# Querying 1896 galaxies took 0.2249038020769755 min.
# No matches!
# Querying 1896 galaxies took 0.23280680974324544 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['HATLAS_RED_1770', 'HATLAS_RED_2150', 'HATLAS_RED_2071']
# --------------------------------
# This query took 0.02974625825881958 min.
# Querying 1896 galaxies took 0.24149880011876423 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 5
# Total number of subbands = 9
# 3 target(s) with ALMA data = ['J133947.34+300725.7', 'HATLAS_RED_1342', 'HATLAS_RED_1341']
# --------------------------------
# This query took 0.027668404579162597 min.
# Querying 1896 galaxies took 0.23344126145044963 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 9
# Total number of subbands = 9
# 3 target(s) with ALMA data = ['J132051.75+312159.8', 'HATLAS_RED_1526', 'HATLAS_RED_1830']
# --------------------------------
# This query took 0.02770991325378418 min.
# Querying 1896 galaxies took 0.239720352490743 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 11
# Total number of subbands = 11
# 4 target(s) with ALMA data = ['J130125.07+284038.0', '3C_326_N', '9658', '3C326N']
# --------------------------------
# This query took 0.02916609843571981 min.
# Querying 1896 galaxies took 0.23964959780375164 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HATLAS_RED_1561']
# --------------------------------
# This query took 0.02411015033721924 min.
# Querying 1896 galaxies took 0.2650684912999471 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HS1549-6']
# --------------------------------
# This query took 0.025248225529988608 min.
# Querying 1896 galaxies took 0.24106076161066692 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 6
# Number of unique subbands = 18
# Total number of subbands = 18
# 6 target(s) with ALMA data = ['SDSS_J123253.23+153625.3', 'J133944.15+274635.2', 'PGC046123', '8952-6104', '324315', 'J1220+2916']
# --------------------------------
# This query took 0.036002620061238604 min.
# Querying 1896 galaxies took 0.23653153578440347 min.
# --------------------------------
# Number of projects = 11
# Number of observations = 16
# Number of unique subbands = 64
# Total number of subbands = 64
# 2 target(s) with ALMA data = ['J1353+1435', '93078']
# --------------------------------
# This query took 0.041155282656351724 min.
# Querying 1896 galaxies took 0.25720104376475017 min.
# No matches!
# Querying 1896 galaxies took 0.2411855936050415 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['J1228+3706', 'HATLAS_RED_2098']
# --------------------------------
# This query took 0.027222585678100587 min.
# Querying 1896 galaxies took 0.23668678601582846 min.
# No matches!
# Querying 1896 galaxies took 0.25911494096120197 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['J0854+2006']
# --------------------------------
# This query took 0.0384537935256958 min.
# Querying 1896 galaxies took 0.225949231783549 min.
# No matches!
# Querying 1896 galaxies took 0.23244038422902424 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['HATLAS_RED_1552', 'HATLAS_RED_1816', 'HATLAS_RED_1943']
# --------------------------------
# This query took 0.030797044436136883 min.
# Querying 1896 galaxies took 0.252988068262736 min.
# No matches!
# Querying 1896 galaxies took 0.25629543463389076 min.
# No matches!
# Querying 1896 galaxies took 0.26412447293599445 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 7
# Total number of subbands = 7
# 3 target(s) with ALMA data = ['J132035.40+340821.7', 'IRASF13182+3424', '8492']
# --------------------------------
# This query took 0.03440879583358765 min.
# Querying 1896 galaxies took 0.24040583769480386 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HATLAS_RED_2007']
# --------------------------------
# This query took 0.027204883098602296 min.
# Querying 1896 galaxies took 0.3264664769172668 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 8
# Number of unique subbands = 16
# Total number of subbands = 29
# 5 target(s) with ALMA data = ['CIG501', 'J132443.68+323225.0', 'HATLAS_RED_1524', 'HATLAS_RED_1589', 'NGC4395']
# --------------------------------
# This query took 0.04001659552256266 min.
# Querying 1896 galaxies took 0.3123198668162028 min.
# No matches!
# Querying 1896 galaxies took 0.3257105628649394 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 6
# Total number of subbands = 6
# 2 target(s) with ALMA data = ['5456', 'SDSS_093507.06+261806.5']
# --------------------------------
# This query took 0.02692017952601115 min.
# Querying 1896 galaxies took 0.36433142026265464 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 5
# Total number of subbands = 5
# 2 target(s) with ALMA data = ['J131047.64+294235.6', 'HATLAS_RED_1898']
# --------------------------------
# This query took 0.026929291089375813 min.
# Querying 1896 galaxies took 0.29144204457600914 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 9
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['NGC_4922', 'NGC_4274']
# --------------------------------
# This query took 0.03258252143859863 min.
# Querying 1896 galaxies took 0.2859571576118469 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['NGC6004', 'hs1549']
# --------------------------------
# This query took 0.027432179450988768 min.
# Querying 1896 galaxies took 0.27941670020421344 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 7
# Total number of subbands = 7
# 3 target(s) with ALMA data = ['J134017.95+262058.3', '8952-12701', 'HATLAS_RED_2085']
# --------------------------------
# This query took 0.029429837067921957 min.
# Querying 1896 galaxies took 0.3034908453623454 min.
# --------------------------------
# Number of projects = 15
# Number of observations = 27
# Number of unique subbands = 107
# Total number of subbands = 117
# 5 target(s) with ALMA data = ['J1606+1814', 'HATLAS_RED_1359', 'HATLAS_RED_1778', 'UGC_9618_N', 'UGC 9618 N']
# --------------------------------
# This query took 0.0844899336496989 min.
# Querying 1896 galaxies took 0.28723735014597573 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 24
# Total number of subbands = 47
# 5 target(s) with ALMA data = ['GRB210610B', 'GRB210610A', 'NGP-94843', 'R02', 'HATLAS_RED_1997']
# --------------------------------
# This query took 0.0528566042582194 min.
# Querying 1896 galaxies took 0.23555959860483805 min.
# No matches!
# Querying 1896 galaxies took 0.2364239533742269 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['RXCJ1603.6+1553']
# --------------------------------
# This query took 0.024664398034413657 min.
# Querying 1896 galaxies took 0.24522008895874023 min.
# No matches!
# Querying 1896 galaxies took 0.25137176911036174 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 6
# Number of unique subbands = 19
# Total number of subbands = 23
# 4 target(s) with ALMA data = ['CIG_268', '7', 'CP_8241_12705', 'R05']
# --------------------------------
# This query took 0.044568816820780434 min.
# Querying 1896 galaxies took 0.31588415304819745 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['CIG494', '587741490891325518_8241-3704']
# --------------------------------
# This query took 0.03327611684799194 min.
# Querying 1896 galaxies took 0.2498847206433614 min.
# No matches!
# Querying 1896 galaxies took 0.25120683908462527 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['RFGC2966', 'HATLAS_RED_2145', 'Abell_1795']
# --------------------------------
# This query took 0.03053121566772461 min.
# Querying 1896 galaxies took 0.2512642661730448 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['SDSS_144151.70+201401.8', 'J081107.38+164304.1']
# --------------------------------
# This query took 0.02606010834376017 min.
# Querying 1896 galaxies took 0.3041494170824687 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 11
# Total number of subbands = 11
# 4 target(s) with ALMA data = ['AGC_174522', 'TXS0828+193', 'J0832+1832', '2379']
# --------------------------------
# This query took 0.03279775778452555 min.
# Querying 1896 galaxies took 0.3172152042388916 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 6
# Number of unique subbands = 18
# Total number of subbands = 24
# 4 target(s) with ALMA data = ['J112531.90+290311.3', '587741421099155681_8241-3703', '2276_444_53712', 'H01']
# --------------------------------
# This query took 0.03579925298690796 min.
# Querying 1896 galaxies took 0.2840196847915649 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['UGC04240']
# --------------------------------
# This query took 0.02219556172688802 min.
# Querying 1896 galaxies took 0.2940522789955139 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['NGC_4150', 'NGC2596']
# --------------------------------
# This query took 0.02727972666422526 min.
# Querying 1896 galaxies took 0.2500750064849854 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['NGC_3245', '587741533840670747_8241-6102']
# --------------------------------
# This query took 0.031274592876434325 min.
# Querying 1896 galaxies took 0.2549633741378784 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 5
# Number of unique subbands = 12
# Total number of subbands = 20
# 1 target(s) with ALMA data = ['NGC3504']
# --------------------------------
# This query took 0.038096328576405845 min.
# Querying 1896 galaxies took 0.2448856512705485 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['SDSS_112907.44+254729.2']
# --------------------------------
# This query took 0.024430592854817707 min.
# Querying 1896 galaxies took 0.24448529084523518 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 27
# Number of unique subbands = 93
# Total number of subbands = 107
# 12 target(s) with ALMA data = ['J1014+2301', '8982-6104', 'GMP3071', 'GMP4060', 'GMP3816', 'MCG+05-31-035', 'LEDA_3098096', 'IC4040', 'GMP3271', 'GMP3779', 'J130713.20+280249.0', 'J130636.39+275222.6']
# --------------------------------
# This query took 0.0929997444152832 min.
# Querying 1896 galaxies took 0.2507150332132975 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 3 target(s) with ALMA data = ['2MASXJ13333299+2616190', '2MASXJ13010083+2701312', 'Ganymede']
# --------------------------------
# This query took 0.030873970190684 min.
# Querying 1896 galaxies took 0.23549081087112428 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 19
# Number of unique subbands = 50
# Total number of subbands = 74
# 9 target(s) with ALMA data = ['HATLAS_RED_1854', '8950-12705', 'ngc4889', 'LEDA_83707', 'GMP4232', 'GMP2374', 'GMP2910', 'GMP3896', 'GMP2923']
# --------------------------------
# This query took 0.060802181561787925 min.
# Querying 1896 galaxies took 0.25498218139012657 min.
# --------------------------------
# Number of projects = 17
# Number of observations = 36
# Number of unique subbands = 127
# Total number of subbands = 141
# 1 target(s) with ALMA data = ['J1303+2433']
# --------------------------------
# This query took 0.12805153926213583 min.
# Querying 1896 galaxies took 0.25298933585484823 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 10
# Number of unique subbands = 32
# Total number of subbands = 40
# 5 target(s) with ALMA data = ['IRAS_10565+2448', 'IRAS10565+2448', 'F10565+2448', 'IRAS_F10565+2448', 'IRAS_F10565+2448_2']
# --------------------------------
# This query took 0.04594953060150146 min.
# Querying 1896 galaxies took 0.2377601424853007 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 3
# Total number of subbands = 3
# 1 target(s) with ALMA data = ['J1116+2200']
# --------------------------------
# This query took 0.022224771976470947 min.
# Querying 1896 galaxies took 0.22776403824488323 min.
# No matches!
# Querying 1896 galaxies took 0.23331923087437947 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['PGC043387', 'SDSS_135637.14+214625.0']
# --------------------------------
# This query took 0.03186972141265869 min.
# Querying 1896 galaxies took 0.24789925813674926 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 1
# Total number of subbands = 1
# 1 target(s) with ALMA data = ['J130801.65+264555.3']
# --------------------------------
# This query took 0.02705647945404053 min.
# Querying 1896 galaxies took 0.2776197552680969 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 10
# Number of unique subbands = 26
# Total number of subbands = 40
# 4 target(s) with ALMA data = ['NGC2903', 'NGC_2903', 'ngc2903', 'ngc_2903']
# --------------------------------
# This query took 0.045064409573872886 min.
# Querying 1896 galaxies took 0.2540996273358663 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 5
# Total number of subbands = 9
# 3 target(s) with ALMA data = ['J130329.08+263301.7', 'HATLAS_RED_1689', 'HATLAS_RED_1659']
# --------------------------------
# This query took 0.027916006247202554 min.
# Querying 1896 galaxies took 0.28876240650812784 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 8
# Number of unique subbands = 28
# Total number of subbands = 32
# 3 target(s) with ALMA data = ['HerBS-139', 'HATLAS_RED_2143', 'HATLAS_RED_1991']
# --------------------------------
# This query took 0.04213176170984904 min.
# Querying 1896 galaxies took 0.23760982354482016 min.
# --------------------------------
# Number of projects = 18
# Number of observations = 21
# Number of unique subbands = 77
# Total number of subbands = 80
# 1 target(s) with ALMA data = ['J0840+1312']
# --------------------------------
# This query took 0.03409520387649536 min.
# Querying 1896 galaxies took 0.2386954466501872 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['MCG+02-21-013']
# --------------------------------
# This query took 0.027936458587646484 min.
# Querying 1896 galaxies took 0.243290642897288 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['3100']
# --------------------------------
# This query took 0.02220231294631958 min.
# Querying 1896 galaxies took 0.24437162081400554 min.
# No matches!
# Querying 1896 galaxies took 0.2371365547180176 min.
# --------------------------------
# Number of projects = 26
# Number of observations = 42
# Number of unique subbands = 141
# Total number of subbands = 162
# 6 target(s) with ALMA data = ['J1224+2122', 'J1224+213', 'J1224+213; B1222+216', '4C_21.35', '587742060530696249_8450-6102', '1224+213 Phase']
# --------------------------------
# This query took 0.04150337775548299 min.
# Querying 1896 galaxies took 0.2385483463605245 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 5
# Number of unique subbands = 21
# Total number of subbands = 21
# 2 target(s) with ALMA data = ['Callisto', 'Ganymede']
# --------------------------------
# This query took 0.03293059666951497 min.
# Querying 1896 galaxies took 0.24806595245997112 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['RFGC3064', 'J1104+2134', 'PGC84348']
# --------------------------------
# This query took 0.0320534348487854 min.
# Querying 1896 galaxies took 0.2406766931215922 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['IC1062', 'PGC95545']
# --------------------------------
# This query took 0.02631036043167114 min.
# Querying 1896 galaxies took 0.2398441791534424 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 11
# Total number of subbands = 16
# 2 target(s) with ALMA data = ['39326', 'HATLAS_RED_1428']
# --------------------------------
# This query took 0.03245396216710408 min.
# Querying 1896 galaxies took 0.23632243871688843 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 5
# Number of unique subbands = 15
# Total number of subbands = 16
# 3 target(s) with ALMA data = ['Mrk_463', 'AGC_9727', 'J1518+1403']
# --------------------------------
# This query took 0.04235245784123739 min.
# Querying 1896 galaxies took 0.24194275140762328 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['596099']
# --------------------------------
# This query took 0.021797919273376466 min.
# Querying 1896 galaxies took 0.24933464129765828 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 15
# Number of unique subbands = 46
# Total number of subbands = 60
# 8 target(s) with ALMA data = ['NGC3239', 'UGC_06697', 'KUG1141+200', '2MASX_J11434983+1958343', 'NGC_3859', 'KUG_1140+202A', '33288', '124350']
# --------------------------------
# This query took 0.05494487682978312 min.
# Querying 1896 galaxies took 0.23632823228836058 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 10
# Total number of subbands = 10
# 2 target(s) with ALMA data = ['NGC_5936', '6796']
# --------------------------------
# This query took 0.030840957164764406 min.
# Querying 1896 galaxies took 0.2298251509666443 min.
# No matches!
# Querying 1896 galaxies took 0.24067331155141194 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 5
# Number of unique subbands = 14
# Total number of subbands = 17
# 3 target(s) with ALMA data = ['2777_258_54554', 'H03', 'RFGC3069']
# --------------------------------
# This query took 0.03614185253779093 min.
# Querying 1896 galaxies took 0.24589090744654338 min.
# No matches!
# Querying 1896 galaxies took 0.2342685063680013 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['HATLAS_RED_1571']
# --------------------------------
# This query took 0.030074151357014973 min.
# Querying 1896 galaxies took 0.2416673461596171 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 2
# Number of unique subbands = 8
# Total number of subbands = 8
# 2 target(s) with ALMA data = ['10828', '2MASX_J13441569+1933596']
# --------------------------------
# This query took 0.026274232069651286 min.
# Querying 1896 galaxies took 0.03405855496724446 min.
# No matches!
# Querying 1896 galaxies took 0.23667500416437784 min.
# No matches!
# Querying 1896 galaxies took 0.2717685341835022 min.
# No matches!
# Querying 1896 galaxies took 0.42500515778859455 min.
# No matches!
# Querying 1896 galaxies took 0.2736197034517924 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['7567']
# --------------------------------
# This query took 0.021491185824076334 min.
# Querying 1896 galaxies took 0.2386128346125285 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 14
# Total number of subbands = 14
# 4 target(s) with ALMA data = ['SMG_6', '387663', 'PGC1439637', '5082']
# ...
# --------------------------------
# This query took 0.045351473490397136 min.
# Querying 1896 galaxies took 0.29987667401631674 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 36
# Total number of subbands = 48
# 12 target(s) with ALMA data = ['1237674651535867994', 'HATLAS1009', 'HATLAS863', 'HATLAS331', 'HATLAS318', 'HATLAS1018', 'Zwicky_3146', 'zwicky_3146', 'zw_3146', 'HATLAS_RED_1043', '122117', '168778']
# --------------------------------
# This query took 0.056451507409413654 min.
# Querying 1896 galaxies took 0.34744275410970055 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 4
# 2 target(s) with ALMA data = ['rs0107', 'rs0105']
# --------------------------------
# This query took 0.025476519266764322 min.
# Querying 1896 galaxies took 0.3946078141530355 min.
# --------------------------------
# Number of projects = 8
# Number of observations = 13
# Number of unique subbands = 52
# Total number of subbands = 52
# 6 target(s) with ALMA data = ['PJ183+05', 'PSOJ183+05', 'P183+05', 'PSO_J183.1124+05.0926', 'P183+05C1', 'P183+05C2']
# --------------------------------
# This query took 0.03263145685195923 min.
# Querying 1896 galaxies took 0.2950645963350932 min.
# No matches!
# Querying 1896 galaxies took 0.3002755085627238 min.
# No matches!
# Querying 1896 galaxies took 0.31919613281885784 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 4
# Number of unique subbands = 16
# Total number of subbands = 16
# 4 target(s) with ALMA data = ['Ceres', '1237655124470661181', '246603', '14265']
# --------------------------------
# This query took 0.03314747412999471 min.
# Querying 1896 galaxies took 0.2672004461288452 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 8
# Number of unique subbands = 31
# Total number of subbands = 31
# 3 target(s) with ALMA data = ['IRAS_08572+3915', 'IRAS 08572+3915', '239192']
# --------------------------------
# This query took 0.038323259353637694 min.
# Querying 1896 galaxies took 0.25793020327885946 min.
# --------------------------------
# Number of projects = 9
# Number of observations = 13
# Number of unique subbands = 49
# Total number of subbands = 49
# 6 target(s) with ALMA data = ['IRAS_08572+3915', 'IRAS 08572+3915', '8655-12705', 'PKS0034-01', '3C15', 'J0029-0113']
# --------------------------------
# This query took 0.049474585056304934 min.
# Querying 1896 galaxies took 0.29734525283177693 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 8
# Number of unique subbands = 28
# Total number of subbands = 28
# 6 target(s) with ALMA data = ['HCG25b', '8086-3704', '588015508213989555_8077-6104', 'rQSO_J232650.86+005116.9', '8155-6101', '8084-12705']
# --------------------------------
# This query took 0.044917221864064535 min.
# Querying 1896 galaxies took 0.3487326661745707 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 28
# Total number of subbands = 28
# 5 target(s) with ALMA data = ['Slug_Nebula', 'J005202', '588015510364880957_8082-6103', 'SMG_5', 'SDSS_074755.45+192910.5']
# --------------------------------
# This query took 0.0355425755182902 min.
# Querying 1896 galaxies took 0.26336753368377686 min.
# No matches!
# Querying 1896 galaxies took 0.22747923930486044 min.
# No matches!
# Querying 1896 galaxies took 0.24157174030939738 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 8
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['NGC_4189', 'SN1997dq']
# --------------------------------
# This query took 0.03233649333318075 min.
# Querying 1896 galaxies took 0.2350783626238505 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 2
# Total number of subbands = 2
# 1 target(s) with ALMA data = ['11014']
# --------------------------------
# This query took 0.022547284762064617 min.
# Querying 1896 galaxies took 0.22820556163787842 min.
# No matches!
# Querying 1896 galaxies took 0.33997195164362587 min.
# --------------------------------
# Number of projects = 13
# Number of observations = 20
# Number of unique subbands = 71
# Total number of subbands = 78
# 9 target(s) with ALMA data = ['588015508731723912_8655-9102', '1237663783669334090', 'J0016-0015', '1237663783663960074', 'SHELA_z4_697739', 'Cosmic_skidmark', '8082-12704', 'dm0027+00_I097', 'dm0027+00_I098']
# --------------------------------
# This query took 0.0701006571451823 min.
# Querying 1896 galaxies took 0.3815137306849162 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 11
# Number of unique subbands = 38
# Total number of subbands = 42
# 11 target(s) with ALMA data = ['1237663784210464777', '8083-12703', '8085-6104', '8081-3702', '9194-3702', 'PM1_9194_3702', 'WP_8078_12703', 'WP_8083_12703', '8084-6103', 'SMM_J030277', 'SHELA_z4_905249']
# --------------------------------
# This query took 0.06882304350535075 min.
# Querying 1896 galaxies took 0.2698453744252523 min.
# No matches!
# Querying 1896 galaxies took 0.2300700028737386 min.
# No matches!
# Querying 1896 galaxies took 0.24492732286453248 min.
# No matches!
# Querying 1896 galaxies took 0.23570175568262736 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['474401']
# --------------------------------
# This query took 0.024892890453338624 min.
# Querying 1896 galaxies took 0.22479667663574218 min.
# No matches!
# Querying 1896 galaxies took 0.2241251587867737 min.
# No matches!
# Querying 1896 galaxies took 0.2139642079671224 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 12
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['Mammoth_Nebula', 'SMG_14']
# --------------------------------
# This query took 0.028279165426890056 min.
# Querying 1896 galaxies took 0.2232202967007955 min.
# No matches!
# Querying 1896 galaxies took 0.2396218736966451 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 5
# Number of unique subbands = 9
# Total number of subbands = 17
# 5 target(s) with ALMA data = ['AGC_5737', 'SMG_8', 'SMG_6', 'SMG_4', '624421']
# --------------------------------
# This query took 0.03402949571609497 min.
# Querying 1896 galaxies took 0.23939943710962933 min.
# --------------------------------
# Number of projects = 12
# Number of observations = 21
# Number of unique subbands = 65
# Total number of subbands = 79
# 8 target(s) with ALMA data = ['NGC_3351', '3C296', 'PGC214240', 'AGC_9162', 'NGC3351', 'M95', '3C_296', '3856']
# --------------------------------
# This query took 0.05471694072087606 min.
# Querying 1896 galaxies took 0.2615726232528687 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 7
# Number of unique subbands = 16
# Total number of subbands = 24
# 6 target(s) with ALMA data = ['NGC_4216', 'AGC_6206', 'IRAS_11506+1331', '68973', '475128', '272690']
# --------------------------------
# This query took 0.04021348555882772 min.
# Querying 1896 galaxies took 0.24800193707148235 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['355825']
# --------------------------------
# This query took 0.023045074939727784 min.
# Querying 1896 galaxies took 0.25647993087768556 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 3
# Number of unique subbands = 8
# Total number of subbands = 12
# 2 target(s) with ALMA data = ['NGC_4698', '123106']
# --------------------------------
# This query took 0.03451225757598877 min.
# Querying 1896 galaxies took 0.26010886828104657 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 2
# Number of unique subbands = 4
# Total number of subbands = 8
# 1 target(s) with ALMA data = ['NGC_4698']
# --------------------------------
# This query took 0.02901873191197713 min.
# Querying 1896 galaxies took 0.2406126578648885 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 5
# Number of unique subbands = 8
# Total number of subbands = 20
# 4 target(s) with ALMA data = ['SMG_8', 'SMG_12', 'SMG_4', 'NGC_4299']
# --------------------------------
# This query took 0.037841049830118816 min.
# Querying 1896 galaxies took 0.24596793651580812 min.
# --------------------------------
# Number of projects = 4
# Number of observations = 4
# Number of unique subbands = 13
# Total number of subbands = 13
# 3 target(s) with ALMA data = ['IRAS_10378+1109', 'IRAS_10378+1108', '232409']
# --------------------------------
# This query took 0.03681165377298991 min.
# Querying 1896 galaxies took 0.23017611106236777 min.
# No matches!
# Querying 1896 galaxies took 0.24293720324834187 min.
# No matches!
# Querying 1896 galaxies took 0.2482768177986145 min.
# No matches!
# Querying 1896 galaxies took 0.23701086441675823 min.
# No matches!
# Querying 1896 galaxies took 0.23199607133865358 min.
# No matches!
# Querying 1896 galaxies took 0.24023158550262452 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['10.30_ch14_pz269660_32']
# --------------------------------
# This query took 0.028148734569549562 min.
# Querying 1896 galaxies took 0.25812495946884156 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['25.687_ch14_pz346854_126']
# --------------------------------
# This query took 0.02658429543177287 min.
# Querying 1896 galaxies took 0.22668091456095377 min.
# No matches!
# Querying 1896 galaxies took 0.22620739539464316 min.
# No matches!
# Querying 1896 galaxies took 0.2317028323809306 min.
# --------------------------------
# Number of projects = 7
# Number of observations = 18
# Number of unique subbands = 36
# Total number of subbands = 72
# 4 target(s) with ALMA data = ['NGC5248', 'NGC_5248', '618039', '189167']
# --------------------------------
# This query took 0.045485583941141765 min.
# Querying 1896 galaxies took 0.229964021841685 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 5
# Number of unique subbands = 20
# Total number of subbands = 20
# 3 target(s) with ALMA data = ['J1516+0701', 'UGC9799', '308811']
# --------------------------------
# This query took 0.03650663693745931 min.
# Querying 1896 galaxies took 0.22431224981943768 min.
# No matches!
# Querying 1896 galaxies took 0.23349347511927288 min.
# --------------------------------
# Number of projects = 3
# Number of observations = 7
# Number of unique subbands = 27
# Total number of subbands = 27
# 2 target(s) with ALMA data = ['SDSS_164922.21+264710.5', 'IRAS_15250+3609']
# --------------------------------
# This query took 0.04891405900319417 min.
# Querying 1896 galaxies took 0.25641144116719566 min.
# No matches!
# Querying 1896 galaxies took 0.26718042691548666 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 7
# Number of unique subbands = 19
# Total number of subbands = 27
# 3 target(s) with ALMA data = ['NGC3626', '2360_167_53728', 'H02']
# --------------------------------
# This query took 0.047681291898091636 min.
# Querying 1896 galaxies took 0.24527573585510254 min.
# No matches!
# Querying 1896 galaxies took 0.29098491271336874 min.
# No matches!
# Querying 1896 galaxies took 0.2830786148707072 min.
# --------------------------------
# Number of projects = 5
# Number of observations = 13
# Number of unique subbands = 32
# Total number of subbands = 52
# 12 target(s) with ALMA data = ['HATLAS1063', 'HATLAS788', 'HATLAS965', 'HATLAS861', 'HATLAS794', 'HATLASJ115317.4-010123', 'HATLASJ121908.7-010159', 'JO204_CO10', 'JO204_CO21', '114808', 'HATLASJ121908', 'HATLASJ115317']
# --------------------------------
# This query took 0.06101547876993815 min.
# Querying 1896 galaxies took 0.3538206140200297 min.
# --------------------------------
# Number of projects = 17
# Number of observations = 27
# Number of unique subbands = 96
# Total number of subbands = 102
# 15 target(s) with ALMA data = ['2J091448.7-003533', 'SN_2015bn', '527928', 'GAMA574200', 'APEX_SB11', 'APEX_SB15', 'HerBS-100', 'SN2015bn', '9J090952.3-003019', 'HATLAS_J092614.4-000744', 'HATLAS_J090940.8-002757', 'J0940-0028', 'J090655.44-000152.7', 'HATLAS1669', 'HATLAS752']
# --------------------------------
# This query took 0.11359568834304809 min.
# Querying 1896 galaxies took 0.3820075432459513 min.
# --------------------------------
# Number of projects = 6
# Number of observations = 12
# Number of unique subbands = 34
# Total number of subbands = 42
# 8 target(s) with ALMA data = ['HATLAS_J143430.9+004133', 'HATLAS852', 'HATLAS1661', 'HATLAS1691', 'HATLAS680', 'G14-1', 'HATLAS_RED_1290', 'HATLAS_RED_1215']
# --------------------------------
# This query took 0.05564472675323486 min.
# Querying 1896 galaxies took 0.23725335995356242 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 4
# Number of unique subbands = 6
# Total number of subbands = 14
# 4 target(s) with ALMA data = ['631801', '620714', '408880', '2322']
# --------------------------------
# This query took 0.03300170501073201 min.
# Querying 1896 galaxies took 0.21987979412078856 min.
# No matches!
# Querying 1896 galaxies took 0.23037411371866862 min.
# --------------------------------
# Number of projects = 1
# Number of observations = 1
# Number of unique subbands = 4
# Total number of subbands = 4
# 1 target(s) with ALMA data = ['PGC57475']
# --------------------------------
# This query took 0.03342937231063843 min.
# Querying 1896 galaxies took 0.289442773660024 min.
# No matches!
# Querying 1896 galaxies took 0.24134174982706705 min.
# --------------------------------
# Number of projects = 2
# Number of observations = 9
# Number of unique subbands = 28
# Total number of subbands = 35
# 5 target(s) with ALMA data = ['UGC_06697', '2MASX_J11443212+2006238', 'KUG_1141+204', 'KUG1140+202B', 'J1114+1939']
# --------------------------------
# This query took 0.041988631089528404 min.
# Querying 1896 galaxies took 0.24161893526713055 min.
# No matches!
# Querying 1896 galaxies took 0.2297310471534729 min.
# No matches!
# Querying 1896 galaxies took 0.32379724979400637 min.
# --------------------------------
# Number of projects = 9
# Number of observations = 15
# Number of unique subbands = 54
# Total number of subbands = 58
# 14 target(s) with ALMA data = ['HATLAS_J142559.2-003552', '1237648720684449913', 'D15-3', 'GAMA570227', 'GAMA567624', 'HATLAS_RED_1190', 'APEX_SB13', 'APEX_SB31', 'FJ141832.96-002825.0', 'CGCG013-092', 'HATLAS879', 'HATLAS1758', 'HATLAS786', 'HATLAS340']
# --------------------------------
# This query took 0.07206152677536011 min.
# Querying 1896 galaxies took 0.47285228172938026 min.
# --------------------------------
# Number of projects = 14
# Number of observations = 21
# Number of unique subbands = 68
# Total number of subbands = 80
# 17 target(s) with ALMA data = ['HATLAS_J142416.7-000218', 'SDSS_J115130.95-000439.9', 'GAMA593680', '244217', 'HATLAS_RED_2460', 'UGC9299', 'HOT2_EI_CII_G09.v2.45', 'HOT2_EI_CII_G09.v2.170', 'J1222-0007', 'SN2002ao', 'PM1_9512_3704', 'G09.v2.45', 'HATLAS1750', 'G12.DR1.354', 'HATLAS1714', 'ugc9299', 'HATLAS808']
# --------------------------------
# This query took 0.09204405148824056 min.
# Querying 1896 galaxies took 0.5024425347646078 min.
# --------------------------------
# Number of projects = 28
# Number of observations = 45
# Number of unique subbands = 146
# Total number of subbands = 155
# 15 target(s) with ALMA data = ['J1516+0015', '1237648721763827882', 'J1133+0015', '645479', 'GAMA619098', 'GAMA618906', 'GAMA618935', '65228', 'HOT2_EI_CII_G09.v2.48', 'HOT2_EI_CII_G09.v2.80', '3J085828.5+003814', 'HATLAS968', 'HATLAS931', 'G09.v2.48', 'GAMA622429']
# --------------------------------
# This query took 0.15174559354782105 min.

# %%
# concatenate queries from Jobs

files = glob.glob('/arc/projects/salvage/ALMAxmatch/ALminer_output/*Nov14*')

myquery_list = []
for f in files:
    myquery_list.append(pandas.read_pickle(f))
    
myquery = pandas.concat(myquery_list)

# %%
alminer.summary(myquery)
# Out:
# --------------------------------
# Number of projects = 990
# Number of observations = 4025
# Number of unique subbands = 9780
# Total number of subbands = 16326
# 1123 target(s) with ALMA data = ['242308', 'NGC_4698', '10.30_ch14_pz269660_32', 'HATLAS_J142559.2-003552', '1237648720684449913', 'D15-3', 'GAMA570227', 'GAMA567624', 'HATLAS_RED_1190', 'APEX_SB13', 'APEX_SB31', 'FJ141832.96-002825.0', 'CGCG013-092', 'HATLAS879', 'HATLAS1758', 'HATLAS786', 'HATLAS340', 'IC1062', 'PGC95545', '34968', 'IRAS_01166-0844', 'HATLAS_RED_832', 'HATLASJ085750.1+012807', '5_bd6_33', 'HOT2_EI_CII_G09.v2.235', 'HOT2_EI_CII_G09.v2.60', 'HATLAS_J085753.1+012332', 'HATLAS_J085021.6+010503', 'HATLAS_J084532.7+011802', '6J090038.0+012810', 'G09.v2.235', 'HATLASJ085750', 'AGC_4552', '480606', 'AT2018hyz', 'J0909+013', 'J0909+0121', 'HATLAS_RED_959', 'AS2COS0157.1', 'XrayOpt_TDE1_ASASSN-18z', 'COS850.0157', 'J1313', 'HOT2_EI_CII_G09.v2.137', 'HATLAS_J084552.0+011121', 'SDP.1160', 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167', 'Q09498+0155', 'COSMOSVLA3_291', 'GEMS-N4636-18', 'Ceres', 'UGC07824', 'HATLAS1179', 'G09.v2.167', 'G09.v2.137', 'HATLAS1679', 'J0103+1526', 'PM1_9195_3702', '015028', 'IRAS_10565+2448', 'IRAS10565+2448', 'F10565+2448', 'IRAS_F10565+2448', 'IRAS_F10565+2448_2', 'NGC3596', '26634', 'RFGC296', '1237657070091960362', 'IMS_J2204+0112', 'SHELA_z4_678917', 'QSO_J0138-0005', 'Q01322-0051', '8080-3704', 'QSO 0138-0005', '8081-9101', 'WP_8085_3704', '587731512617664623_8154-9102', 'IMSJ2204+0112', 'NGC3626', '2360_167_53728', 'H02', 'SMG_6', '387663', 'PGC1439637', '5082', 'VV847', '170103', 'NGC_3245', '587741533840670747_8241-6102', 'Mammoth_Nebula', 'SMG_14', 'MACSJ2155.6+1231', 'J2222+1213', '7815-12705', 'manga_7977-3704', 'J112531.90+290311.3', '587741421099155681_8241-3703', '2276_444_53712', 'H01', 'J1512+0203', 'J1111+0228', 'G09.v2.107', '323889', 'APEX_SB17', 'HATLASJ085616.0+005237', 'PG0934+013', 'PG_0934+013', 'HOT2_EI_CII_G09.v2.107', 'J085547.66+004739.4', 'HATLASJ085616', 'SDSS_164922.21+264710.5', 'IRAS_15250+3609', 'SDSS013527-1039', 'Neptune', 'SDSS_J213333.31-071249.2', 'PGC57475', 'UGC_06697', '2MASX_J11443212+2006238', 'KUG_1141+204', 'KUG1140+202B', 'J1114+1939', '588015508731723912_8655-9102', '1237663783669334090', 'J0016-0015', '1237663783663960074', 'SHELA_z4_697739', 'Cosmic_skidmark', '8082-12704', 'dm0027+00_I097', 'dm0027+00_I098', '640213', '67202', '609961', 'HATLAS_RED_1547', 'HATLAS_RED_1823', '113989', 'NGC_4189', 'SN1997dq', '4C+29.30', 'SDSS_081958.64+262311.3', '2J091448.7-003533', 'SN_2015bn', '527928', 'GAMA574200', 'APEX_SB11', 'APEX_SB15', 'HerBS-100', 'SN2015bn', '9J090952.3-003019', 'HATLAS_J092614.4-000744', 'HATLAS_J090940.8-002757', 'J0940-0028', 'J090655.44-000152.7', 'HATLAS1669', 'HATLAS752', '587731513694355564_8155-6102', '9io9', 'pg_0157+001', 'SHELA_z4_554210', 'HERS1', 'Mrk1014', 'hers1', 'PJ020941.3', '8081-9102', 'IRAS_01572+0009', 'CP_8078_6104', 'J1516+0701', 'UGC9799', '308811', '3100', '299299', '456147', 'GAMA496966', 'RXCJ1504.1-0248', 'APX_SB2_5', 'HATLAS_RED_2007', 'NGC_4150', 'NGC2596', '1237652901308793003', 'J2358-1020', 'J1108+0659', 'G08-5', 'dm0916+06_I040', 'dm0916+06_I039', 'HATLAS_RED_1571', 'AGN8', 'ADF22', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', 'NBJ-CFHT-C343', 'SSA22-AZ001', 'SSA22-AZ010', 'AzTEC14', 'AzTEC1', 'mADF22', 'Core_region', 'ALMAJ221737.43+001710.7', 'eADF22tile1', 'SSA22-AzTEC14', 'SSA22-AzTEC1', 'WHDF-LAB-03', 'ALMAJ221731.95+001820.3', 'UGC01123', 'SSA22-AzTEC105', 'ADF22.A1', 'ADF22.A5', '8086-9101', 'ADF22.A4', 'ADF22.A7', 'ADF22.10', 'ADF22.A8', 'ADF22.A12', 'ADF22.15', 'ADF22.A17', 'ADF22.A16', 'PM2_8153_12702', 'CP_7968_12705', 'dm0052+00_I116', 'dm0052+00_I115', 'SSA.0007', 'DSFG4', 'DSFG1', 'RXCJ2341.1+0018', 'SSA.0001', 'SSA.0029', 'WP_8085_12701', '3FGL_J0056.3-0935', 'Pallas', 'J132838.16+333618.3', 'J133306.57+330903.7', 'HS1549-6', '25.687_ch14_pz346854_126', 'GRB210610B', 'GRB210610A', 'NGP-94843', 'R02', 'HATLAS_RED_1997', '2777_258_54554', 'H03', 'RFGC3069', 'M100', 'NGC_4321', 'SN2020oi', '373633', 'ngc4321', 'J0909 ...
# --------------------------------

# %%
alminer.plot_overview(myquery)

# %% [markdown]
# ## Match myquery catalog back to SDSS RA/Dec to get redshifts for each observation

# %%
ra_query, dec_query = np.array(myquery['RAJ2000']), np.array(myquery['DEJ2000'])

# %%
objID_query = []
z_query = []

for ra_q, dec_q in zip(ra_query, dec_query):
    
    diff = np.sqrt((ra_sdss-ra_q)**2 + (dec_sdss-dec_q)**2)
    
    if np.min(diff) > 30:
        print('Poor match!')
    
    objID_query.append(table_id[diff == np.min(diff)][0])
    z_query.append(z_sdss[diff == np.min(diff)][0])

z_query = np.array(z_query)

# %% [markdown]
# In the future I can replace the spatial_scale_max with an SDSS radius...

# %%
rf_12CO_10 = 115.27120180 #GHz

redshifted_line = rf_12CO_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 69
# Number of observations = 357
# Number of unique subbands = 230
# Total number of subbands = 366
# 318 target(s) with ALMA data = ['242308', 'HATLAS_J142559.2-003552', 'GAMA570227', 'GAMA567624', 'CGCG013-092', 'HOT2_EI_CII_G09.v2.235', 'HOT2_EI_CII_G09.v2.60', 'HATLAS_J085753.1+012332', 'HATLAS_J085021.6+010503', '6J090038.0+012810', 'AGC_4552', 'J0909+013', 'J0909+0121', 'HATLAS_J084552.0+011121', 'HOT2_EI_CII_G09.v2.137', 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167', 'COSMOSVLA3_291', 'PM1_9195_3702', '26634', 'RFGC296', 'Q01322-0051', '8080-3704', '8081-9101', 'WP_8085_3704', '587731512617664623_8154-9102', '387663', '5082', '170103', '7815-12705', 'manga_7977-3704', '587741421099155681_8241-3703', '323889', 'HATLASJ085616.0+005237', 'HOT2_EI_CII_G09.v2.107', '588015508731723912_8655-9102', 'Cosmic_skidmark', 'J0016-0015', '8082-12704', '67202', '609961', '113989', '2J091448.7-003533', '527928', 'GAMA574200', '9J090952.3-003019', 'HATLAS_J092614.4-000744', 'HATLAS_J090940.8-002757', '587731513694355564_8155-6102', '8081-9102', 'CP_8078_6104', '308811', '3100', '299299', '456147', 'GAMA496966', 'NGC_4150', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', 'ALMAJ221737.43+001710.7', '8086-9101', 'PM2_8153_12702', 'CP_7968_12705', 'WP_8085_12701', 'RFGC3069', 'M100', '373633', 'NGC_4321', 'RFGC229', '8655-3701', 'HELMS_RED_385', '8623-12702', '8616-1902', '8655-1902', 'WP_8616_9101', '2993', 'HATLASJ091956.9+013852', '13J090238.7+013253', '12J090234.3+012518', 'HATLAS_J092131.0+013432', 'AGC191728', '11107', '123106', '618039', '189167', '7964-1902', 'PM1_8615_1901', 'PM1_8623_1902', '587731173842027508_8623-6104', '8615-9101', '8623-6104', 'HATLAS_J142416.7-000218', 'GAMA593680', '244217', 'HOT2_EI_CII_G09.v2.170', 'HOT2_EI_CII_G09.v2.45', 'PM1_9512_3704', '8941-3701', '8149-12704', 'HATLAS_J143430.9+004133', 'AGC_5737', '624421', '538220', '10993', 'CP_9195_9101', '12494', '588015510364880957_8082-6103', '7598', '321551', '7987', '5456', 'IRAS_F10173+0828', 'GAMA417678', 'HOT2_EI_CII_G09.v2.232', '263667', '8952-6104', '324315', 'HATLASJ090223.9-001639', '470573', 'HOT2_EI_CII_G09.v2.55', 'HATLAS_J092156.5-001538', 'AGC_8585', 'J1058+0133', '440644', '501763', 'J1058+015', 'JO201_CO10B', 'JO201_CO10', '150056', '7567', 'NGC_6106', '123988', 'CIG234', 'J2226+0052', 'CIG_268', 'CP_8241_12705', '8952-12701', 'IRAS_F13443+0802', '411612', '656018', '577834', '437037', 'DDO_155', 'HATLAS_J143601.6+022933', '645479', 'GAMA619098', 'GAMA618906', 'GAMA618935', '65228', 'HOT2_EI_CII_G09.v2.48', 'HOT2_EI_CII_G09.v2.80', '3J085828.5+003814', 'A1835', 'Abell 1835', '2408', 'COSMOS-1200839', 'COSMOS-0969208', 'COSMOS-1197519', '265143', 'HATLASJ085957.9+015632', 'HOT2_EI_CII_G09.v2.58', 'HOT2_EI_CII_G09.v2.38', 'HOT2_EI_CII_G09.v2.77', 'COSMOSVLA3_225', '11014', '328009', '545938', '159043', '8083-12703', '8085-6104', '8081-3702', '9194-3702', 'PM1_9194_3702', 'WP_8078_12703', 'WP_8083_12703', '8084-6103', '246603', '14265', 'HATLAS_J143701.0-010421', '29955', 'HATLASJ121253.5-002203', '105386', '658645', '93078', 'HATLASJ115317.4-010123', 'HATLASJ121908.7-010159', 'JO204_CO10', '114808', 'CIG501', 'UGC_9618_N', 'HATLAS_J141235.5+023130', 'HATLAS_J145019.0+015206', 'HATLAS_J144244.2+015846', 'rs0680', 'rs0677', 'rs0679', 'J1410+0203', 'NGC_5331', '653728', 'rs0767', 'GAMA238125', 'GAMA228432', '445641', '318424', 'CP_7977_9102', '587727221402042402_7977-3703', '8618-9102', 'HE0232-0900', '8728-3701', 'PM1_9195_3703', 'J0840+1312', 'RXCJ1350.3+0940', '8492', '640777', 'HATLAS_J145013.2+012125', 'AGC249559', '122665', '136638', 'GAMA239376', 'Neptune', '2MASXJ13333299+2616190', '2MASXJ13010083+2701312', '9658', '587742060530696249_8450-6102', 'CP_8085_6101', '587731512619696292_8084-3702', '8081-12703', '8081-6102', '8655-12705', 'PKS0034-01', '631801', '620714', '408880', '2322', 'J1008+0029', '239192', '530542', 'RFGC3064', 'J1104+2134', 'RXCJ1603.6+1553', '8086-3704', '588015508213989555_8077-6104', '8155-6101', '8084-12705', 'AGC252580', '355825', '4795', '7316', 'A ...
# --------------------------------

# %%
selected.keys(
# Out:
# Index(['Obs', 'project_code', 'ALMA_source_name', 'RAJ2000', 'DEJ2000',
#        'ang_res_arcsec', 'min_freq_GHz', 'max_freq_GHz', 'central_freq_GHz',
#        'bandwidth_GHz', 'freq_res_kHz', 'vel_res_kms', 'LAS_arcsec',
#        'FoV_arcsec', 'cont_sens_bandwidth', 'line_sens_10kms',
#        'line_sens_native', 'MOUS_id', 'collections', 'pi_userid', 'o_ucd',
#        'obs_publisher_did', 'obs_collection', 'facility_name',
#        'instrument_name', 'obs_id', 'dataproduct_type', 'calib_level',
#        'target_name', 's_ra', 's_dec', 's_fov', 's_region', 's_xel1', 's_xel2',
#        'em_xel', 't_xel', 'pol_xel', 's_resolution', 't_min', 't_max',
#        't_exptime', 't_resolution', 'em_min', 'em_max', 'em_res_power',
#        'pol_states', 'access_url', 'access_format', 'access_estsize',
#        'proposal_id', 'data_rights', 'gal_longitude', 'gal_latitude',
#        'band_list', 'em_resolution', 'bandwidth', 'antenna_arrays',
#        'is_mosaic', 'obs_release_date', 'spatial_resolution',
#        'frequency_support', 'frequency', 'velocity_resolution',
#        'obs_creator_name', 'pub_title', 'first_author', 'authors',
#        'pub_abstract', 'publication_year', 'proposal_abstract',
#        'schedblock_name', 'proposal_authors', 'sensitivity_10kms',
#        'cont_sensitivity_bandwidth', 'pwv', 'group_ous_uid', 'member_ous_uid',
#        'asdm_uid', 'obs_title', 'type', 'scan_intent', 'science_observation',
#        'spatial_scale_max', 'qa2_passed', 'bib_reference', 'science_keyword',
#        'scientific_category', 'lastModified', 'pi_name'],
#       dtype='object')

# %%
rf_12CO_10 = 115.27120180 #GHz

redshifted_line = rf_12CO_10/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 68
# Number of observations = 356
# Number of unique subbands = 229
# Total number of subbands = 365
# 317 target(s) with ALMA data = ['242308', 'HATLAS_J142559.2-003552', 'GAMA570227', 'GAMA567624', 'CGCG013-092', 'HOT2_EI_CII_G09.v2.235', 'HOT2_EI_CII_G09.v2.60', 'HATLAS_J085753.1+012332', 'HATLAS_J085021.6+010503', '6J090038.0+012810', 'AGC_4552', 'J0909+013', 'J0909+0121', 'HATLAS_J084552.0+011121', 'HOT2_EI_CII_G09.v2.137', 'HATLAS_J090034.2+011856', 'HOT2_EI_CII_G09.v2.167', 'COSMOSVLA3_291', 'PM1_9195_3702', '26634', 'RFGC296', 'Q01322-0051', '8080-3704', '8081-9101', 'WP_8085_3704', '587731512617664623_8154-9102', '387663', '5082', '170103', '7815-12705', 'manga_7977-3704', '587741421099155681_8241-3703', '323889', 'HATLASJ085616.0+005237', 'HOT2_EI_CII_G09.v2.107', '588015508731723912_8655-9102', 'Cosmic_skidmark', 'J0016-0015', '8082-12704', '67202', '609961', '113989', '2J091448.7-003533', '527928', 'GAMA574200', '9J090952.3-003019', 'HATLAS_J092614.4-000744', 'HATLAS_J090940.8-002757', '587731513694355564_8155-6102', '8081-9102', 'CP_8078_6104', '308811', '3100', '299299', '456147', 'GAMA496966', 'NGC_4150', '587731511545626673_8081-3704', '8077-9101', '587731511545233578_8082-12701', '587731187797393472_8615-3703', 'ALMAJ221737.43+001710.7', '8086-9101', 'PM2_8153_12702', 'CP_7968_12705', 'WP_8085_12701', 'RFGC3069', 'M100', '373633', 'NGC_4321', 'RFGC229', '8655-3701', 'HELMS_RED_385', '8623-12702', '8616-1902', '8655-1902', 'WP_8616_9101', '2993', 'HATLASJ091956.9+013852', '13J090238.7+013253', '12J090234.3+012518', 'HATLAS_J092131.0+013432', 'AGC191728', '11107', '123106', '618039', '189167', '7964-1902', 'PM1_8615_1901', 'PM1_8623_1902', '587731173842027508_8623-6104', '8615-9101', '8623-6104', 'HATLAS_J142416.7-000218', 'GAMA593680', '244217', 'HOT2_EI_CII_G09.v2.170', 'HOT2_EI_CII_G09.v2.45', 'PM1_9512_3704', '8941-3701', '8149-12704', 'HATLAS_J143430.9+004133', 'AGC_5737', '624421', '538220', '10993', 'CP_9195_9101', '12494', '588015510364880957_8082-6103', '7598', '321551', '7987', '5456', 'IRAS_F10173+0828', 'GAMA417678', 'HOT2_EI_CII_G09.v2.232', '263667', '8952-6104', '324315', 'HATLASJ090223.9-001639', '470573', 'HOT2_EI_CII_G09.v2.55', 'HATLAS_J092156.5-001538', 'AGC_8585', 'J1058+0133', '440644', '501763', 'J1058+015', 'JO201_CO10B', 'JO201_CO10', '150056', '7567', 'NGC_6106', '123988', 'CIG234', 'J2226+0052', 'CIG_268', 'CP_8241_12705', '8952-12701', 'IRAS_F13443+0802', '411612', '656018', '577834', '437037', 'DDO_155', 'HATLAS_J143601.6+022933', '645479', 'GAMA619098', 'GAMA618906', 'GAMA618935', '65228', 'HOT2_EI_CII_G09.v2.48', 'HOT2_EI_CII_G09.v2.80', '3J085828.5+003814', 'A1835', 'Abell 1835', '2408', 'COSMOS-1200839', 'COSMOS-0969208', 'COSMOS-1197519', '265143', 'HATLASJ085957.9+015632', 'HOT2_EI_CII_G09.v2.58', 'HOT2_EI_CII_G09.v2.38', 'HOT2_EI_CII_G09.v2.77', 'COSMOSVLA3_225', '11014', '328009', '545938', '159043', '8083-12703', '8085-6104', '8081-3702', '9194-3702', 'PM1_9194_3702', 'WP_8078_12703', 'WP_8083_12703', '8084-6103', '246603', '14265', 'HATLAS_J143701.0-010421', '29955', 'HATLASJ121253.5-002203', '105386', '658645', '93078', 'HATLASJ115317.4-010123', 'HATLASJ121908.7-010159', 'JO204_CO10', '114808', 'CIG501', 'UGC_9618_N', 'HATLAS_J141235.5+023130', 'HATLAS_J145019.0+015206', 'HATLAS_J144244.2+015846', 'rs0680', 'rs0677', 'rs0679', 'J1410+0203', 'NGC_5331', '653728', 'rs0767', 'GAMA238125', 'GAMA228432', '445641', '318424', 'CP_7977_9102', '587727221402042402_7977-3703', '8618-9102', 'HE0232-0900', '8728-3701', 'PM1_9195_3703', 'J0840+1312', 'RXCJ1350.3+0940', '8492', '640777', 'HATLAS_J145013.2+012125', 'AGC249559', '122665', '136638', 'GAMA239376', '2MASXJ13333299+2616190', '2MASXJ13010083+2701312', '9658', '587742060530696249_8450-6102', 'CP_8085_6101', '587731512619696292_8084-3702', '8081-12703', '8081-6102', '8655-12705', 'PKS0034-01', '631801', '620714', '408880', '2322', 'J1008+0029', '239192', '530542', 'RFGC3064', 'J1104+2134', 'RXCJ1603.6+1553', '8086-3704', '588015508213989555_8077-6104', '8155-6101', '8084-12705', 'AGC252580', '355825', '4795', '7316', 'AGC_260164', ...
# --------------------------------

# %%
rf_12CO_21 = 230.53800000 # 12CO J=2-1
redshifted_line = rf_12CO_21/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# Number of projects = 13
# Number of observations = 36
# Number of unique subbands = 34
# Total number of subbands = 36
# 32 target(s) with ALMA data = ['APEX_SB13', 'NGC3626', '2360_167_53728', '2276_444_53712', 'APEX_SB17', '2MASX_J11443212+2006238', 'KUG1140+202B', 'SDSS_081958.64+262311.3', 'APEX_SB15', 'NGC_4321', 'NGC5248', 'NGC3504', 'J1058+0133', 'JO201_CO21', 'JO201_CO21B', 'NGC_4254', 'NGC4395', '0570_537_52266', 'GMP4232', 'GMP2374', 'LEDA_83707', 'GMP3896', 'UM461', 'NGC2903', 'KUG_1140+202A', 'KUG1141+200', '0480_580_51989', 'GMP3816', 'IC4040', 'GMP3779', 'LEDA_3098096', 'NGC_3351']
# --------------------------------
# --------------------------------
# Number of projects = 50
# Number of observations = 253
# Number of unique subbands = 206
# Total number of subbands = 256
# 163 target(s) with ALMA data = ['NGC_4698', '1237648720684449913', 'APEX_SB13', 'APEX_SB31', 'NGC3596', '1237657070091960362', 'NGC3626', '2360_167_53728', 'NGC_3245', 'J112531.90+290311.3', '2276_444_53712', 'APEX_SB17', 'PG0934+013', 'J085547.66+004739.4', 'SDSS_164922.21+264710.5', 'SDSS_J213333.31-071249.2', '2MASX_J11443212+2006238', 'KUG_1141+204', 'KUG1140+202B', '1237663783669334090', '1237663783663960074', 'dm0027+00_I097', 'dm0027+00_I098', 'NGC_4189', 'SDSS_081958.64+262311.3', 'APEX_SB11', 'APEX_SB15', 'J090655.44-000152.7', 'IRAS_01572+0009', 'UGC9799', 'APX_SB2_5', 'NGC2596', '1237652901308793003', 'dm0916+06_I040', 'dm0916+06_I039', 'UGC01123', 'dm0052+00_I116', 'dm0052+00_I115', 'J132838.16+333618.3', 'J133306.57+330903.7', '2777_258_54554', 'NGC_4321', 'NGC4321', 'CGCG_436-030', 'VV492', '1237654030328791126', 'J100217.9+015124', 'NGC5248', 'SDSS_J211333.80-000950.4', 'SDSS_J211307.21+005108.5', 'NGC3504', 'ugc9299', 'J133947.34+300725.7', 'J130329.08+263301.7', 'SDSS_093507.06+261806.5', 'IRAS_F10173+0828', '1237655495979106610', 'J133944.15+274635.2', 'PGC046123', 'J1220+2916', '1237651754549706790', 'J1058+0133', 'dm1106+01_I095', 'dm1106+01_I096', 'JO201_CO21', 'JO201_CO21B', 'NGC_4299', 'SDSS_J143029.88+133912.0', '1237671764248363271', '0379_579_51789', 'J134017.95+262058.3', 'NGC_4254', '1237648721763827882', 'GAMA622429', 'J1516+0015', 'UGC04240', 'CGCG429-012', '1237648722830688271', 'NGC_4383', '1237663784210464777', 'SDSS_144151.70+201401.8', 'SDSS_112907.44+254729.2', 'JO204_CO21', 'J132443.68+323225.0', 'NGC4395', '1237651736305402018', 'J1410+0203', 'APEX_SB14', 'IRAS12112+0305', 'IRASF13497+0220B', 'IRASF13497+0220A', 'SDSS_091358.65+164552.9', 'APX_SB2_3', 'J132051.75+312159.8', 'SDSS_J101043.36+061201.4', '1237649961382772816', 'VV285', 'NGC_985', '1237652630714122400', '1237652901832294517', 'UGC11958', 'J132035.40+340821.7', 'IRASF13182+3424', 'NGC_4419', 'J130125.07+284038.0', 'J1224+2122', '0637_584_52174', '0413_238_51929', 'dm0346+00_I110', 'dm0346+00_I109', '0570_537_52266', 'VV75', 'IRAS_F10190+1322', 'HCG25b', 'dm2227-09', 'SDSS_135637.14+214625.0', 'LEDA_83707', 'GMP4232', 'GMP2374', 'GMP3896', 'NGC_4216', 'SDSS_J150904.22+043441.8', 'SDSS_212639.87+001830.0', '1237657190888898714', 'GAMA272990', 'dm0035-10', '1237674651535867994', 'UM461', 'GAMA177186', 'MCG+02-21-013', 'NGC2903', 'J131047.64+294235.6', 'NGC2595', 'IC2341', 'NGC7194', 'NGC_4274', 'NGC3239', 'KUG1141+200', '2MASX_J11434983+1958343', 'NGC_3859', 'KUG_1140+202A', 'Mrk_463', '1237648705664450617', '1237648704051675158', 'GAMA64646', 'IRAS_F01364-1042', 'IC1079', 'J130801.65+264555.3', 'Abell_1795', '0480_580_51989', 'GMP3071', 'GMP3816', 'MCG+05-31-035', 'LEDA_3098096', 'IC4040', 'GMP3271', 'GMP3779', 'J130713.20+280249.0', 'J130636.39+275222.6', 'NGC_3351', '3C296', 'PGC214240', 'NGC3351']
# --------------------------------

# %%
rf_12CO_32 = 345.79598990 # 12CO J=3-2
redshifted_line = rf_12CO_32/(1+z_query)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   (myquery["ang_res_arcsec"] < 3) & 
                   (myquery["spatial_scale_max"] > 10) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)

selected = myquery[(myquery["min_freq_GHz"] < redshifted_line) & 
                   (myquery["max_freq_GHz"] > redshifted_line) & 
                   ((myquery["scientific_category"] == 'Galaxy evolution') | 
                    (myquery["scientific_category"] == 'Active galaxies') |
                    (myquery["scientific_category"] == 'Cosmology') |
                    (myquery["scientific_category"] == 'Local Universe')) &
                   (myquery["dataproduct_type"] == 'cube')]
alminer.summary(selected)
# Out:
# --------------------------------
# No observations found.
# --------------------------------
# --------------------------------
# Number of projects = 33
# Number of observations = 61
# Number of unique subbands = 57
# Total number of subbands = 63
# 50 target(s) with ALMA data = ['G09.v2.235', 'J0909+0121', 'G09.v2.167', 'G09.v2.137', '015028', 'H02', 'J1512+0203', 'G09.v2.107', 'HATLASJ085616', 'pg_0157+001', 'RXCJ1504.1-0248', 'G08-5', 'H03', 'CGCG436-030', 'HATLASJ091956', 'UGC9299', 'G09.v2.45', 'G14-1', 'SHOC_391', '021348', 'HATLASJ090223', 'G09.v2.55', 'J1058+0133', 'Teacup_AGN', 'J2226+0052', 'J1516+0015', 'G09.v2.48', 'Abell 1835', 'G09.v2.77', 'HATLASJ085957', 'HATLASJ121253', 'RXJ0820.9+0752', 'HATLASJ121908', 'HATLASJ115317', 'IRAS_F12112+0305', 'irasf12112+0305', 'G04-1', '210358', 'S02', 'G09.v2.42', 'ngc2903', 'IRASF01364-1042', 'IRAS01364-1042', 'IRAS_10378+1109', 'G09.v2.52', 'G09.v2.26', 'HATLASJ142057', 'HATLASJ091157', 'G09.v2.103', 'NGC3351']
# --------------------------------
